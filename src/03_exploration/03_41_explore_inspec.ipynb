# %%
import requests
import boto3
import json
import os
import sys
import argparse
import importlib
import transformers
import torch
import pathlib
import smart_open
import awswrangler as wr
from IPython.display import display
from sagemaker.huggingface.processing import HuggingFaceProcessor
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import FrameworkProcessor
from sagemaker.sklearn.estimator import SKLearn
from sagemaker.workflow.steps import ProcessingStep
from sagemaker.workflow.pipeline_context import PipelineSession
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker.session import get_execution_role


# Adding ../01_modules or ./01_modules to the system path so that we can load modules from 
# there as well
if '__file__' in globals():
    script_dir = pathlib.Path(__file__).parent.resolve()
else:
    script_dir = pathlib.Path().absolute()
modules_path_in_dev = os.path.abspath(os.path.join(script_dir, '..', '01_modules'))
modules_path_in_prod = os.path.abspath(os.path.join(script_dir, '01_modules'))
if os.path.exists(modules_path_in_dev):
    sys.path.append(modules_path_in_dev)
if os.path.exists(modules_path_in_prod):
    sys.path.append(modules_path_in_prod)


# # Jupyter only reads a local module the first time after 
# # kernel start. Re-running a cell with 
# # "from mymodulename import *" would not change
# # anything, even if the imported module has since changed.
# # As a workaround, we need to directly load the module, 
# # use importlib.reload to reload it and then import * 
import utils
_ = importlib.reload(utils)
import config
_ = importlib.reload(config)
# Out:
# utils.py loaded: v0.2.12
# config.py loaded: v0.1

# %%
keys = {}
s3_client = boto3.client('s3')
files = s3_client.list_objects(Bucket=config.DEFAULT_S3_BUCKET_NAME, Prefix='01_data/01_raw/inspec/keys/', Delimiter='/', MaxKeys=10000)
for file_ref in files['Contents']:
    source_filepath = file_ref['Key']
    with smart_open.open(f's3://{config.DEFAULT_S3_BUCKET_NAME}/{source_filepath}') as file_source:
        for raw_line in file_source:
            line = raw_line.strip()
            line = line.replace('\t', '\n')
            if not line in keys:
                keys[line] = 0
            keys[line] += 1

sorted_keys = {k: v for k, v in sorted(keys.items(), key=lambda item: item[1], reverse=True)}
print(json.dumps(sorted_keys, indent=2, default=str))
# Out:
# {
#   "Internet": 95,
#   "information resources": 46,
#   "optimisation": 36,
#   "computational complexity": 32,
#   "stability": 28,
#   "human factors": 28,
#   "polynomials": 28,
#   "matrix algebra": 27,
#   "electronic commerce": 27,
#   "robust control": 26,
#   "probability": 26,
#   "control system synthesis": 22,
#   "computational geometry": 22,
#   "artificial intelligence": 21,
#   "differential equations": 21,
#   "closed loop systems": 20,
#   "medical image processing": 20,
#   "statistical analysis": 20,
#   "nonlinear control systems": 19,
#   "feedback": 19,
#   "parallel programming": 19,
#   "iterative methods": 19,
#   "interpolation": 19,
#   "process control": 18,
#   "business data processing": 18,
#   "graph theory": 18,
#   "neural nets": 17,
#   "decision theory": 17,
#   "data mining": 17,
#   "learning (artificial intelligence)": 16,
#   "image reconstruction": 16,
#   "software agents": 16,
#   "approximation theory": 16,
#   "formal logic": 16,
#   "telemedicine": 16,
#   "hypermedia markup languages": 15,
#   "human resource management": 15,
#   "digital simulation": 15,
#   "multi-agent systems": 15,
#   "production control": 15,
#   "mobile computing": 15,
#   "convergence": 15,
#   "linear programming": 15,
#   "optimal control": 15,
#   "personnel": 15,
#   "information systems": 14,
#   "information science": 14,
#   "identification": 13,
#   "position control": 13,
#   "quantum theory": 13,
#   "marketing": 13,
#   "machining": 13,
#   "reliability": 13,
#   "minimisation": 13,
#   "decision support systems": 13,
#   "accounting": 13,
#   "performance evaluation": 13,
#   "finite element analysis": 13,
#   "library automation": 13,
#   "academic libraries": 13,
#   "inference mechanisms": 12,
#   "quantum communication": 12,
#   "genetic algorithms": 12,
#   "initial value problems": 12,
#   "CAD/CAM": 12,
#   "protocols": 12,
#   "client-server systems": 12,
#   "FORTRAN": 12,
#   "object-oriented programming": 12,
#   "electronic publishing": 12,
#   "employment": 12,
#   "asymptotic stability": 11,
#   "adaptive control": 11,
#   "calibration": 11,
#   "scheduling": 11,
#   "dynamic programming": 11,
#   "linear systems": 11,
#   "search problems": 11,
#   "knowledge acquisition": 11,
#   "professional aspects": 11,
#   "temporal logic": 11,
#   "integer programming": 11,
#   "medical diagnostic imaging": 11,
#   "dynamics": 10,
#   "functional programming": 10,
#   "quantum computing": 10,
#   "information theory": 10,
#   "eigenvalues and eigenfunctions": 10,
#   "health care": 10,
#   "dosimetry": 10,
#   "radiation therapy": 10,
#   "medical computing": 10,
#   "knowledge representation": 10,
#   "error analysis": 10,
#   "project management": 10,
#   "Petri nets": 10,
#   "publishing": 10,
#   "artificial life": 10,
#   "investment": 9,
#   "control system analysis": 9,
#   "differentiation": 9,
#   "frequency response": 9,
#   "security of data": 9,
#   "Runge-Kutta methods": 9,
#   "groupware": 9,
#   "user interfaces": 9,
#   "machine tools": 9,
#   "real-time systems": 9,
#   "transport protocols": 9,
#   "decidability": 9,
#   "process algebra": 9,
#   "number theory": 9,
#   "cellular automata": 9,
#   "teaching": 9,
#   "heuristic programming": 9,
#   "computer vision": 9,
#   "social aspects of automation": 9,
#   "uncertain systems": 9,
#   "closed-loop system": 8,
#   "nonlinear systems": 8,
#   "wavelet transforms": 8,
#   "graphical user interfaces": 8,
#   "image processing": 8,
#   "damping": 8,
#   "formal specification": 8,
#   "stochastic processes": 8,
#   "fault diagnosis": 8,
#   "computerised numerical control": 8,
#   "Java": 8,
#   "knowledge based systems": 8,
#   "query processing": 8,
#   "operations research": 8,
#   "convergence of numerical methods": 8,
#   "information technology": 8,
#   "management of change": 8,
#   "classification": 8,
#   "simulation": 8,
#   "discrete time systems": 8,
#   "document handling": 8,
#   "information retrieval": 8,
#   "game theory": 7,
#   "controllability": 7,
#   "partial differential equations": 7,
#   "Lyapunov methods": 7,
#   "robustness": 7,
#   "decision trees": 7,
#   "feature extraction": 7,
#   "tracking": 7,
#   "optimization": 7,
#   "cutting": 7,
#   "software libraries": 7,
#   "boundary-value problems": 7,
#   "Newton method": 7,
#   "electronic data interchange": 7,
#   "continuous time systems": 7,
#   "Markov processes": 7,
#   "mammography": 7,
#   "crosstalk": 7,
#   "planning": 7,
#   "mechanical engineering computing": 7,
#   "management": 7,
#   "workflow management software": 7,
#   "DP management": 7,
#   "simulated annealing": 7,
#   "law administration": 7,
#   "filtering theory": 7,
#   "telecommunication traffic": 7,
#   "stock control": 7,
#   "government data processing": 7,
#   "libraries": 7,
#   "C++ language": 7,
#   "compensation": 7,
#   "education": 7,
#   "transfer functions": 6,
#   "time-varying systems": 6,
#   "neurocontrollers": 6,
#   "backpropagation": 6,
#   "image coding": 6,
#   "image classification": 6,
#   "vibration control": 6,
#   "nonlinear dynamical systems": 6,
#   "stochastic systems": 6,
#   "splines (mathematics)": 6,
#   "parameter estimation": 6,
#   "integral equations": 6,
#   "data structures": 6,
#   "agriculture": 6,
#   "numerical solution": 6,
#   "physics computing": 6,
#   "quantum optics": 6,
#   "fuzzy logic": 6,
#   "pattern recognition": 6,
#   "manufacturing industries": 6,
#   "computer network management": 6,
#   "man-machine systems": 6,
#   "inspection": 6,
#   "computer graphics": 6,
#   "problem solving": 6,
#   "quality of service": 6,
#   "set theory": 6,
#   "queueing theory": 6,
#   "case-based reasoning": 6,
#   "algorithm theory": 6,
#   "physiological models": 6,
#   "computerised tomography": 6,
#   "multimedia communication": 6,
#   "formal verification": 6,
#   "reasoning": 6,
#   "operating systems (computers)": 6,
#   "case study": 6,
#   "retailing": 6,
#   "delays": 6,
#   "online front-ends": 6,
#   "information services": 6,
#   "XML": 6,
#   "time series": 6,
#   "flexible manufacturing systems": 6,
#   "banking": 6,
#   "business communication": 6,
#   "digital libraries": 6,
#   "teleconferencing": 6,
#   "theorem proving": 6,
#   "poles and zeros": 6,
#   "records management": 6,
#   "observers": 6,
#   "cartography": 6,
#   "cognitive systems": 5,
#   "fault tolerance": 5,
#   "scalability": 5,
#   "fuzzy control": 5,
#   "manipulator dynamics": 5,
#   "sensitivity": 5,
#   "image texture": 5,
#   "data compression": 5,
#   "encoding": 5,
#   "numerical analysis": 5,
#   "vibrations": 5,
#   "numerical stability": 5,
#   "functional languages": 5,
#   "performance": 5,
#   "biology computing": 5,
#   "data analysis": 5,
#   "embedded systems": 5,
#   "cryptography": 5,
#   "synchronisation": 5,
#   "distributed object management": 5,
#   "reviews": 5,
#   "parallelising compilers": 5,
#   "bound states": 5,
#   "linearisation techniques": 5,
#   "railways": 5,
#   "image segmentation": 5,
#   "medical \nimage processing": 5,
#   "diagnostic radiography": 5,
#   "expert systems": 5,
#   "financial data processing": 5,
#   "security": 5,
#   "HPF": 5,
#   "information industry": 5,
#   "history": 5,
#   "standards": 5,
#   "uncertainty handling": 5,
#   "equivalence classes": 5,
#   "user \ninterfaces": 5,
#   "management information systems": 5,
#   "accuracy": 5,
#   "cataloguing": 5,
#   "VLSI": 5,
#   "notebook computers": 5,
#   "database management systems": 5,
#   "infrared imaging": 5,
#   "productivity": 5,
#   "constraint theory": 5,
#   "software maintenance": 5,
#   "storage management": 5,
#   "least squares approximations": 5,
#   "computational linguistics": 5,
#   "training": 5,
#   "computer literacy": 5,
#   "educational computing": 5,
#   "user interface": 5,
#   "knowledge engineering": 5,
#   "large-scale systems": 4,
#   "Monte Carlo methods": 4,
#   "biotechnology": 4,
#   "nonlinear control \nsystems": 4,
#   "mobile robots": 4,
#   "evolutionary computation": 4,
#   "intelligent control": 4,
#   "biocontrol": 4,
#   "optical disc storage": 4,
#   "monotonicity": 4,
#   "image sequences": 4,
#   "image recognition": 4,
#   "edge detection": 4,
#   "remote sensing": 4,
#   "parallel architectures": 4,
#   "state feedback": 4,
#   "fractional differentiation": 4,
#   "chaos": 4,
#   "inverse problems": 4,
#   "digital control": 4,
#   "nonlinear \ncontrol systems": 4,
#   "type theory": 4,
#   "optimising compilers": 4,
#   "fault tolerant computing": 4,
#   "file servers": 4,
#   "psychology": 4,
#   "behavioural sciences": 4,
#   "quantum cryptography": 4,
#   "quantum information processing": 4,
#   "open systems": 4,
#   "fuzzy set theory": 4,
#   "fuzzy systems": 4,
#   "noise": 4,
#   "road vehicles": 4,
#   "distributed databases": 4,
#   "condition monitoring": 4,
#   "neural networks": 4,
#   "discrete event simulation": 4,
#   "signal processing": 4,
#   "message passing": 4,
#   "software reusability": 4,
#   "software reliability": 4,
#   "packet switching": 4,
#   "economic cybernetics": 4,
#   "medical image \nprocessing": 4,
#   "biomedical ultrasonics": 4,
#   "image registration": 4,
#   "intensity modulation": 4,
#   "neurophysiology": 4,
#   "gradient methods": 4,
#   "group theory": 4,
#   "computability": 4,
#   "reliability theory": 4,
#   "trees (mathematics)": 4,
#   "diagnostic expert systems": 4,
#   "process monitoring": 4,
#   "computer science education": 4,
#   "formal languages": 4,
#   "complexity": 4,
#   "sorting": 4,
#   "local area networks": 4,
#   "manufacturing resources planning": 4,
#   "budgeting": 4,
#   "parallel languages": 4,
#   "program compilers": 4,
#   "relational databases": 4,
#   "assembly planning": 4,
#   "systems re-engineering": 4,
#   "software development management": 4,
#   "finance": 4,
#   "specification languages": 4,
#   "directed graphs": 4,
#   "wide area networks": 4,
#   "network servers": 4,
#   "business": 4,
#   "advertising": 4,
#   "distance measurement": 4,
#   "topology": 4,
#   "asynchronous transfer mode": 4,
#   "covariance matrices": 4,
#   "e-commerce": 4,
#   "Boolean functions": 4,
#   "laminates": 4,
#   "content management": 4,
#   "survey": 4,
#   "mathematical operators": 4,
#   "network topology": 4,
#   "broadband networks": 4,
#   "telecommunication security": 4,
#   "software packages": 4,
#   "modeling": 4,
#   "authorisation": 4,
#   "resource allocation": 4,
#   "statistical process control": 4,
#   "fuzzy neural nets": 4,
#   "systems analysis": 4,
#   "microactuators": 4,
#   "microfluidics": 4,
#   "computer based training": 4,
#   "accreditation": 4,
#   "buyer's guides": 4,
#   "librarians": 4,
#   "visual perception": 4,
#   "software engineering": 4,
#   "risk management": 4,
#   "cardiology": 4,
#   "continuing education": 4,
#   "airports": 4,
#   "vectors": 4,
#   "logic programming": 4,
#   "telecommunication computing": 4,
#   "experiment": 4,
#   "invariance": 4,
#   "management science": 4,
#   "electric current control": 4,
#   "power system harmonics": 4,
#   "reduced order systems": 4,
#   "MIMO systems": 4,
#   "observability": 4,
#   "goods distribution": 4,
#   "distance learning": 4,
#   "control system \nsynthesis": 4,
#   "geographic information systems": 4,
#   "chemical technology": 3,
#   "predictive control": 3,
#   "matrix \nalgebra": 3,
#   "state estimation": 3,
#   "state \nfeedback": 3,
#   "simulation results": 3,
#   "self-adjusting systems": 3,
#   "unsupervised learning": 3,
#   "robots": 3,
#   "online learning": 3,
#   "radial basis function networks": 3,
#   "recurrent neural nets": 3,
#   "micromachining": 3,
#   "moulding": 3,
#   "image enhancement": 3,
#   "image resolution": 3,
#   "military systems": 3,
#   "decoding": 3,
#   "civil engineering computing": 3,
#   "adaptive signal processing": 3,
#   "Gaussian noise": 3,
#   "principal component analysis": 3,
#   "geophysics computing": 3,
#   "adders": 3,
#   "digital arithmetic": 3,
#   "positioning": 3,
#   "manipulators": 3,
#   "vibration isolation": 3,
#   "calculus": 3,
#   "actuators": 3,
#   "motion control": 3,
#   "polynomial approximation": 3,
#   "integration": 3,
#   "variational techniques": 3,
#   "controllers": 3,
#   "frequency stability": 3,
#   "parallel \nlanguages": 3,
#   "functional \nprogramming": 3,
#   "Web sites": 3,
#   "syntax": 3,
#   "concurrency control": 3,
#   "auditing": 3,
#   "software standards": 3,
#   "Hilbert space": 3,
#   "qubits": 3,
#   "Hilbert spaces": 3,
#   "numerical simulation": 3,
#   "error correction": 3,
#   "braking": 3,
#   "Banach spaces": 3,
#   "series (mathematics)": 3,
#   "ordinary differential equations": 3,
#   "difference equations": 3,
#   "mathematical model": 3,
#   "friction": 3,
#   "steam turbines": 3,
#   "information \nresources": 3,
#   "vector quantisation": 3,
#   "arc welding": 3,
#   "pipeline processing": 3,
#   "virtual reality": 3,
#   "virtual \nreality": 3,
#   "rendering (computer graphics)": 3,
#   "recursive functions": 3,
#   "Turing machines": 3,
#   "hidden Markov models": 3,
#   "speech recognition": 3,
#   "grammars": 3,
#   "telecommunication network routing": 3,
#   "finite automata": 3,
#   "cooperative systems": 3,
#   "duality (mathematics)": 3,
#   "complementarity": 3,
#   "computational speed": 3,
#   "performance measures": 3,
#   "state-space methods": 3,
#   "cancer": 3,
#   "biomedical MRI": 3,
#   "tumours": 3,
#   "mathematical morphology": 3,
#   "fractals": 3,
#   "image quality": 3,
#   "computer simulation": 3,
#   "determinants": 3,
#   "treatment planning": 3,
#   "control system": 3,
#   "simulated \nannealing": 3,
#   "entropy": 3,
#   "random processes": 3,
#   "failure analysis": 3,
#   "wear": 3,
#   "computer aided production planning": 3,
#   "heat transfer": 3,
#   "finite difference methods": 3,
#   "wavelet \ntransforms": 3,
#   "educational courses": 3,
#   "manufacturers": 3,
#   "middleware": 3,
#   "costing": 3,
#   "purchasing": 3,
#   "customer relationship management": 3,
#   "manufacturing": 3,
#   "numerical approximations": 3,
#   "parallel processing": 3,
#   "enterprise resource planning": 3,
#   "manufacturing data processing": 3,
#   "application program interfaces": 3,
#   "software performance evaluation": 3,
#   "bisimulation equivalence": 3,
#   "finite state machines": 3,
#   "feedforward neural nets": 3,
#   "very large databases": 3,
#   "concurrent engineering": 3,
#   "transaction processing": 3,
#   "town and country \nplanning": 3,
#   "knowledge \nrepresentation": 3,
#   "heuristics": 3,
#   "Internet telephony": 3,
#   "outsourcing": 3,
#   "frequency-domain analysis": 3,
#   "time-domain analysis": 3,
#   "system recovery": 3,
#   "High Performance Fortran": 3,
#   "compiler": 3,
#   "software performance \nevaluation": 3,
#   "software portability": 3,
#   "information \nretrieval": 3,
#   "search engines": 3,
#   "correlation methods": 3,
#   "indexing": 3,
#   "FIR filters": 3,
#   "driver information systems": 3,
#   "video coding": 3,
#   "WWW": 3,
#   "concurrent systems": 3,
#   "pattern \nrecognition": 3,
#   "automata theory": 3,
#   "completeness": 3,
#   "manufacturing processes": 3,
#   "structural engineering computing": 3,
#   "CAD": 3,
#   "engineering graphics": 3,
#   "piezoelectric actuators": 3,
#   "analogue-digital conversion": 3,
#   "learning": 3,
#   "context-free languages": 3,
#   "learning (artificial \nintelligence)": 3,
#   "UK": 3,
#   "telecommunication congestion control": 3,
#   "telecommunication network \nrouting": 3,
#   "fault detection": 3,
#   "radio networks": 3,
#   "software reviews": 3,
#   "bifurcation": 3,
#   "hysteresis": 3,
#   "document image processing": 3,
#   "surface fitting": 3,
#   "logic design": 3,
#   "geometry": 3,
#   "diffusion": 3,
#   "thermodynamics": 3,
#   "flaw detection": 3,
#   "economics": 3,
#   "videoconferencing": 3,
#   "mesh generation": 3,
#   "recovery": 3,
#   "disasters": 3,
#   "Taiwan": 3,
#   "genetic algorithm": 3,
#   "public key cryptography": 3,
#   "World Wide Web": 3,
#   "Web site": 3,
#   "contracts": 3,
#   "text analysis": 3,
#   "measurement errors": 3,
#   "inheritance": 3,
#   "IT": 3,
#   "metadata": 3,
#   "modelling": 3,
#   "composites": 3,
#   "speech processing": 3,
#   "stock markets": 3,
#   "software": 3,
#   "patients": 3,
#   "certification": 3,
#   "literature review": 3,
#   "DP industry": 3,
#   "object-oriented methods": 3,
#   "user centred design": 3,
#   "communication": 3,
#   "collaboration": 3,
#   "aerospace control": 3,
#   "travel industry": 3,
#   "elliptic equations": 3,
#   "polynomial": 3,
#   "social sciences": 3,
#   "zeros": 3,
#   "microcontrollers": 3,
#   "eigenvalues": 3,
#   "boundary integral equations": 3,
#   "conjugate gradient methods": 3,
#   "cellular radio": 3,
#   "multilayer perceptrons": 3,
#   "experiments": 3,
#   "document management": 3,
#   "fault location": 3,
#   "pattern classification": 3,
#   "visual communication": 3,
#   "piecewise linear techniques": 3,
#   "multivariable control systems": 3,
#   "mean square error methods": 3,
#   "adaptive estimation": 3,
#   "natural sciences computing": 3,
#   "computer games": 3,
#   "travel \nindustry": 3,
#   "tree searching": 3,
#   "thermoacoustic tomography": 3,
#   "thermoacoustics": 3,
#   "lung": 3,
#   "hotel industry": 3,
#   "data privacy": 3,
#   "internal stresses": 3,
#   "tuning": 3,
#   "variable structure systems": 3,
#   "power supply quality": 3,
#   "active filters": 3,
#   "power harmonic filters": 3,
#   "town and country planning": 3,
#   "CASC": 3,
#   "high level languages": 3,
#   "philosophical aspects": 2,
#   "individual rationality": 2,
#   "large scale systems": 2,
#   "higher order statistics": 2,
#   "control system analysis computing": 2,
#   "paper industry": 2,
#   "three-term control": 2,
#   "Hebbian learning": 2,
#   "self-adjusting \nsystems": 2,
#   "radial basis functions": 2,
#   "neural architecture": 2,
#   "nonparametric statistics": 2,
#   "brain models": 2,
#   "timing": 2,
#   "weight": 2,
#   "cost": 2,
#   "optical polymers": 2,
#   "recording capacity": 2,
#   "interconnections": 2,
#   "deconvolution": 2,
#   "focal planes": 2,
#   "image \nreconstruction": 2,
#   "image sampling": 2,
#   "codes": 2,
#   "error statistics": 2,
#   "optical fibre networks": 2,
#   "system buses": 2,
#   "CCD image sensors": 2,
#   "principal component \nanalysis": 2,
#   "Laplace equations": 2,
#   "quantisation (signal)": 2,
#   "copyright protection": 2,
#   "remote \nsensing": 2,
#   "terrain mapping": 2,
#   "storage requirements": 2,
#   "information content": 2,
#   "data integrity": 2,
#   "spectral analysis": 2,
#   "parallel computing": 2,
#   "passive vibration control": 2,
#   "stabilization": 2,
#   "feedback control": 2,
#   "transient response": 2,
#   "control design": 2,
#   "feedback systems": 2,
#   "trajectory control": 2,
#   "fractional calculus": 2,
#   "partial differential \nequations": 2,
#   "impulse response": 2,
#   "multiple processors": 2,
#   "Haskell": 2,
#   "entangled state": 2,
#   "fault \ntolerance": 2,
#   "programming language semantics": 2,
#   "rational choice theory": 2,
#   "accountability": 2,
#   "computer viruses": 2,
#   "fidelity": 2,
#   "analytical solution": 2,
#   "Alice": 2,
#   "Bob": 2,
#   "quantum states": 2,
#   "atomic clusters": 2,
#   "nuclear magnetic resonance": 2,
#   "entanglement": 2,
#   "computation theory": 2,
#   "quantum gates": 2,
#   "reflectivity": 2,
#   "atom-photon collisions": 2,
#   "quantum \ncomputing": 2,
#   "fuzzy rules": 2,
#   "bending": 2,
#   "intelligent actuators": 2,
#   "car-caravan snaking": 2,
#   "automobiles": 2,
#   "operator splitting": 2,
#   "numerical approximation": 2,
#   "Newton \nmethod": 2,
#   "nonlinear differential equations": 2,
#   "matrix decomposition": 2,
#   "Taylor series": 2,
#   "extrapolation": 2,
#   "Hermitian matrices": 2,
#   "initial-boundary value problems": 2,
#   "haemodynamics": 2,
#   "patient care": 2,
#   "supervisory control": 2,
#   "interactive systems": 2,
#   "computerised monitoring": 2,
#   "sensors": 2,
#   "corporate modelling": 2,
#   "technological \nforecasting": 2,
#   "feature recognition algorithms": 2,
#   "National Design Repository": 2,
#   "concavity": 2,
#   "mechanical engineering": 2,
#   "CORBA": 2,
#   "file organisation": 2,
#   "medical information systems": 2,
#   "computer network reliability": 2,
#   "Halden Reactor Project": 2,
#   "Web": 2,
#   "computerised instrumentation": 2,
#   "measurement standards": 2,
#   "voxel size": 2,
#   "database technology": 2,
#   "Lyapunov matrix equations": 2,
#   "TCP": 2,
#   "interactivity": 2,
#   "multicast communication": 2,
#   "distributed database": 2,
#   "mobile \ncomputing": 2,
#   "transaction \nprocessing": 2,
#   "queries": 2,
#   "differential games": 2,
#   "minimax techniques": 2,
#   "stochastic games": 2,
#   "computational time": 2,
#   "distance functions": 2,
#   "linear \nsystem": 2,
#   "NP-complete problem": 2,
#   "iteration": 2,
#   "variance reduction": 2,
#   "bootstrap": 2,
#   "biological organs": 2,
#   "sensitivity analysis": 2,
#   "quantum entanglement": 2,
#   "specificity": 2,
#   "X-ray optics": 2,
#   "fields": 2,
#   "thorax \nphantom": 2,
#   "maximum likelihood estimation": 2,
#   "mammogram synthesis": 2,
#   "3D simulation": 2,
#   "fractal dimension": 2,
#   "X-ray image acquisition": 2,
#   "biological tissues": 2,
#   "image \nregistration": 2,
#   "Boltzmann equation": 2,
#   "intensity modulated radiation therapy": 2,
#   "Monte \nCarlo methods": 2,
#   "medical \ndiagnostic imaging": 2,
#   "robotic systems": 2,
#   "metallurgical industries": 2,
#   "linear orders": 2,
#   "critical point": 2,
#   "element orders": 2,
#   "recursive estimation": 2,
#   "CPU time": 2,
#   "engineering computing": 2,
#   "tolerance analysis": 2,
#   "plastic deformation": 2,
#   "radial directions": 2,
#   "fast Fourier transform": 2,
#   "fast Fourier transforms": 2,
#   "vibration measurement": 2,
#   "ANOVA": 2,
#   "computer networks": 2,
#   "induction motor drives": 2,
#   "convergence speed": 2,
#   "random noise": 2,
#   "enterprise resource \nplanning": 2,
#   "implementation": 2,
#   "factory automation": 2,
#   "negotiation": 2,
#   "CRM": 2,
#   "heat equation": 2,
#   "numerical integration": 2,
#   "differential \nequations": 2,
#   "technological forecasting": 2,
#   "generalization": 2,
#   "fluctuations": 2,
#   "self-organised criticality": 2,
#   "finite volume methods": 2,
#   "product development": 2,
#   "software \ndevelopment management": 2,
#   "software tools": 2,
#   "network protocol": 2,
#   "distributed systems": 2,
#   "dynamic response": 2,
#   "parallel \nprogramming": 2,
#   "scientific computing": 2,
#   "computation tree logic": 2,
#   "compilers": 2,
#   "quantitative analysis": 2,
#   "knowledge \nacquisition": 2,
#   "SQL": 2,
#   "intelligent design assistants": 2,
#   "business rules": 2,
#   "knowledge-based approach": 2,
#   "functional structure": 2,
#   "knowledge-based system": 2,
#   "conceptual model": 2,
#   "multi-agent \nsystems": 2,
#   "human-computer interaction": 2,
#   "user modelling": 2,
#   "organization": 2,
#   "knowledge management": 2,
#   "operating system": 2,
#   "compatibility": 2,
#   "e-business": 2,
#   "back-up procedures": 2,
#   "FIR models": 2,
#   "tax preparation": 2,
#   "HPF compiler": 2,
#   "parallel performance": 2,
#   "distributed shared memory systems": 2,
#   "High-Performance Fortran": 2,
#   "Monte Carlo simulation": 2,
#   "finite element method": 2,
#   "parallel programs": 2,
#   "parallel computation": 2,
#   "CMOS logic circuits": 2,
#   "logic CAD": 2,
#   "low-power electronics": 2,
#   "benchmark": 2,
#   "matrix \nmultiplication": 2,
#   "data locality": 2,
#   "information analysis": 2,
#   "information needs": 2,
#   "universities": 2,
#   "commerce": 2,
#   "public libraries": 2,
#   "computation": 2,
#   "convolution": 2,
#   "parallel algorithms": 2,
#   "software \nagents": 2,
#   "diagnostic reasoning": 2,
#   "time warp simulation": 2,
#   "simulation \nlanguages": 2,
#   "storage \nmanagement": 2,
#   "adaptive filters": 2,
#   "digital filters": 2,
#   "sequential programs": 2,
#   "reconfigurable computing": 2,
#   "DSP": 2,
#   "industrial property": 2,
#   "semantic networks": 2,
#   "dependence graphs": 2,
#   "linear time algorithm": 2,
#   "self-reproduction": 2,
#   "microcomputer applications": 2,
#   "peripheral interfaces": 2,
#   "programmable controllers": 2,
#   "Chebyshev approximation": 2,
#   "network infrastructure": 2,
#   "human resources": 2,
#   "software architecture": 2,
#   "HVAC": 2,
#   "interoperability": 2,
#   "visual design steering": 2,
#   "large-scale multidisciplinary design optimization": 2,
#   "optimal design problems": 2,
#   "image morphing": 2,
#   "complex systems": 2,
#   "numerical optimization": 2,
#   "boundary-elements methods": 2,
#   "closed-form solution": 2,
#   "composite materials": 2,
#   "intelligent structures": 2,
#   "stability analysis": 2,
#   "0.35 \nmicron": 2,
#   "current-mode circuits": 2,
#   "tolerance \nanalysis": 2,
#   "desktop publishing": 2,
#   "bioelectric potentials": 2,
#   "white noise": 2,
#   "Fokker-Planck equation": 2,
#   "biology": 2,
#   "context-sensitive languages": 2,
#   "neural chips": 2,
#   "rational transfer functions": 2,
#   "law \nadministration": 2,
#   "physics \ncomputing": 2,
#   "resource \nallocation": 2,
#   "internetworking": 2,
#   "user performance": 2,
#   "telecommunication \nnetwork routing": 2,
#   "electromagnetic coupling": 2,
#   "telecommunication \nsecurity": 2,
#   "optimization problem": 2,
#   "digital signal processing chips": 2,
#   "colour graphics": 2,
#   "graphics": 2,
#   "nonlinear system": 2,
#   "workflow": 2,
#   "printing": 2,
#   "workflow \nmanagement software": 2,
#   "Hadamard matrices": 2,
#   "graph colouring": 2,
#   "singular perturbation theory": 2,
#   "genetics": 2,
#   "proteins": 2,
#   "necessary conditions": 2,
#   "Wiener filters": 2,
#   "minimization": 2,
#   "heuristic": 2,
#   "synthetic aperture radar": 2,
#   "parameter \nestimation": 2,
#   "threshold logic": 2,
#   "image \nsegmentation": 2,
#   "lighting": 2,
#   "Kalman filters": 2,
#   "nonlinear filters": 2,
#   "image colour analysis": 2,
#   "materials handling": 2,
#   "batch processing (industrial)": 2,
#   "production \nengineering computing": 2,
#   "industrial robots": 2,
#   "least squares \napproximations": 2,
#   "integrated circuit packaging": 2,
#   "production \ncontrol": 2,
#   "compliance": 2,
#   "yield improvement": 2,
#   "numerical results": 2,
#   "efficiency": 2,
#   "competitive advantage": 2,
#   "safety-critical software": 2,
#   "electrostatic actuators": 2,
#   "convergence rate": 2,
#   "relaxation theory": 2,
#   "air traffic control": 2,
#   "system documentation": 2,
#   "industrial systems": 2,
#   "intelligent system": 2,
#   "user manuals": 2,
#   "task analysis": 2,
#   "radiation pressure": 2,
#   "mechanical contact": 2,
#   "microprocessor chips": 2,
#   "disaster planning": 2,
#   "filtration": 2,
#   "budgeting data processing": 2,
#   "globalization": 2,
#   "legislation": 2,
#   "information dissemination": 2,
#   "quality control": 2,
#   "testing": 2,
#   "monolithic top-shooting microinjector": 2,
#   "drops": 2,
#   "ink jet printers": 2,
#   "call centres": 2,
#   "microcomputers": 2,
#   "mail": 2,
#   "mailing systems": 2,
#   "mobile": 2,
#   "wireless LAN": 2,
#   "Microsoft Windows": 2,
#   "frame relay": 2,
#   "ATM": 2,
#   "service providers": 2,
#   "digital content": 2,
#   "content \nmanagement": 2,
#   "businesses": 2,
#   "Groove Networks": 2,
#   "Kontiki": 2,
#   "aggregator": 2,
#   "emergency services": 2,
#   "video databases": 2,
#   "cyclotrons": 2,
#   "LIS": 2,
#   "light interferometers": 2,
#   "temperature control": 2,
#   "microwave oscillators": 2,
#   "two-phase flow": 2,
#   "pipe flow": 2,
#   "modal analysis": 2,
#   "signal sampling": 2,
#   "light interferometry": 2,
#   "temperature measurement": 2,
#   "pressure measurement": 2,
#   "level measurement": 2,
#   "flow measurement": 2,
#   "C language": 2,
#   "C++": 2,
#   "management \neducation": 2,
#   "embedded Linux": 2,
#   "public domain software": 2,
#   "portals": 2,
#   "library": 2,
#   "Galerkin method": 2,
#   "wave propagation": 2,
#   "nonlinear equations": 2,
#   "redundancy": 2,
#   "natural language processing": 2,
#   "context-free grammars": 2,
#   "digital library": 2,
#   "electronic mail": 2,
#   "firmware": 2,
#   "librarianship": 2,
#   "three-dimensional displays": 2,
#   "interface design": 2,
#   "automation": 2,
#   "human \nfactors": 2,
#   "ergonomics": 2,
#   "aircraft control": 2,
#   "spin glasses": 2,
#   "surgery": 2,
#   "radiology": 2,
#   "primary care": 2,
#   "eye": 2,
#   "biomedical education": 2,
#   "patient treatment": 2,
#   "Semantic Web": 2,
#   "natural language": 2,
#   "situation calculus": 2,
#   "collision avoidance": 2,
#   "path planning": 2,
#   "object-oriented design": 2,
#   "cellular biophysics": 2,
#   "molecular \nbiophysics": 2,
#   "NASA Johnson Space Center": 2,
#   "teamwork": 2,
#   "marketing data processing": 2,
#   "mathematical modelling": 2,
#   "viscosity": 2,
#   "statistical \nanalysis": 2,
#   "operator equations": 2,
#   "Bezier curves": 2,
#   "B-spline": 2,
#   "Web services": 2,
#   "trust": 2,
#   "multiple axis machining": 2,
#   "flow control": 2,
#   "character sets": 2,
#   "fluid dynamics": 2,
#   "uncertainty": 2,
#   "heat conduction": 2,
#   "functions": 2,
#   "generating functions": 2,
#   "Jacobian matrices": 2,
#   "telecommunication network reliability": 2,
#   "Bessel functions": 2,
#   "lower bound": 2,
#   "linguistics": 2,
#   "self-reproducing automata": 2,
#   "face recognition": 2,
#   "handicapped aids": 2,
#   "air pollution": 2,
#   "partial \ndifferential equations": 2,
#   "parabolic equations": 2,
#   "superconductivity": 2,
#   "free energy": 2,
#   "finite element \nanalysis": 2,
#   "wavelet transform": 2,
#   "linear equations": 2,
#   "metaheuristics": 2,
#   "genetic \nalgorithms": 2,
#   "adaptive systems": 2,
#   "formal model": 2,
#   "forecasting theory": 2,
#   "information storage": 2,
#   "information sharing": 2,
#   "cost savings": 2,
#   "NP-hard problem": 2,
#   "search \nproblems": 2,
#   "polynomial time algorithm": 2,
#   "data envelopment analysis": 2,
#   "production": 2,
#   "space heating": 2,
#   "power consumption": 2,
#   "business intelligence": 2,
#   "information \ntechnology": 2,
#   "rectifying circuits": 2,
#   "circuit simulation": 2,
#   "time-varying channels": 2,
#   "blind equalisers": 2,
#   "eigenvalues and \neigenfunctions": 2,
#   "mobile \nrobots": 2,
#   "Runge-Kutta \nmethods": 2,
#   "smart cards": 2,
#   "statistical databases": 2,
#   "chemistry computing": 2,
#   "entertainment": 2,
#   "industrial plants": 2,
#   "company": 2,
#   "job": 2,
#   "multimedia computing": 2,
#   "job satisfaction": 2,
#   "sparse matrices": 2,
#   "constraint handling": 2,
#   "transportation": 2,
#   "exponential distribution": 2,
#   "operations \nresearch": 2,
#   "bipartite matching algorithm": 2,
#   "convex programming": 2,
#   "nonlinear programming": 2,
#   "ERP systems": 2,
#   "dynamic \nprogramming": 2,
#   "benefits": 2,
#   "distance education": 2,
#   "computer aided instruction": 2,
#   "construction industry": 2,
#   "Web browser": 2,
#   "retrieval": 2,
#   "capacity constraints": 2,
#   "mechanical stability": 2,
#   "acoustic tomography": 2,
#   "Fourier transforms": 2,
#   "linear \nsystems": 2,
#   "angiocardiography": 2,
#   "hemoglobin": 2,
#   "optical tomography": 2,
#   "sensor fusion": 2,
#   "management education": 2,
#   "sales": 2,
#   "courseware": 2,
#   "message authentication": 2,
#   "China": 2,
#   "thermal power stations": 2,
#   "commissioning": 2,
#   "healthcare": 2,
#   "invoicing": 2,
#   "staff development": 2,
#   "government policies": 2,
#   "politics": 2,
#   "velocity control": 2,
#   "sequences": 2,
#   "general constitutive description": 2,
#   "inelastic behavior": 2,
#   "failure behavior": 2,
#   "fibrous \nlaminates": 2,
#   "micromechanics": 2,
#   "layer-by-layer analysis": 2,
#   "stress analysis": 2,
#   "fibre reinforced composites": 2,
#   "elastoplasticity": 2,
#   "nonmonotonic reasoning": 2,
#   "midcareer librarians": 2,
#   "library profession": 2,
#   "job market": 2,
#   "technology transfer": 2,
#   "academic library": 2,
#   "career change": 2,
#   "bibliographies": 2,
#   "gender issues": 2,
#   "causality": 2,
#   "multilayer feedforward neural networks": 2,
#   "two-term control": 2,
#   "binary sequences": 2,
#   "modules": 2,
#   "method of moments": 2,
#   "filtering": 2,
#   "closed-loop \nstability": 2,
#   "integral processes": 2,
#   "dead-time": 2,
#   "disturbance response": 2,
#   "sufficient condition": 2,
#   "power system stability": 2,
#   "sampled data systems": 2,
#   "switching circuits": 2,
#   "bridge circuits": 2,
#   "power \nsystem control": 2,
#   "power system control": 2,
#   "control \nperformance": 2,
#   "algorithm": 2,
#   "land information systems": 2,
#   "town \nand country planning": 2,
#   "cadastre": 2,
#   "globalisation": 2,
#   "accounting software": 2,
#   "percolation": 2,
#   "educational technology": 2,
#   "Australia": 2,
#   "international trade": 2,
#   "United States": 2,
#   "closed-loop systems": 2,
#   "CASC-JC": 2,
#   "CADE ATP \nSystem Competition": 2,
#   "theorem \nproving": 2,
#   "semantics": 2,
#   "EMTP": 2,
#   "H/sup infinity / control": 2,
#   "sales management": 2,
#   "design": 2,
#   "autonomous agents": 2,
#   "conversation protocols": 2,
#   "separate-account industry": 1,
#   "Web-based platforms": 1,
#   "independent money managers": 1,
#   "financial advisors": 1,
#   "classicism": 1,
#   "universality": 1,
#   "classical component of mind": 1,
#   "human cognition": 1,
#   "universal generalization": 1,
#   "connectionist models": 1,
#   "classical symbol \nsystems": 1,
#   "syntax-sensitive rules": 1,
#   "causal explanations": 1,
#   "mental processes": 1,
#   "philosophy of mind": 1,
#   "Information-Based Semantics": 1,
#   "Content Atomism": 1,
#   "IBS": 1,
#   "Language \nof Thought": 1,
#   "LOT": 1,
#   "cognitive states": 1,
#   "beliefs": 1,
#   "desires": 1,
#   "world-making": 1,
#   "selective representing": 1,
#   "mental representations": 1,
#   "organisms": 1,
#   "realism": 1,
#   "mind-independent world": 1,
#   "cognitive profiles": 1,
#   "Lob Theorem": 1,
#   "limitation on mechanism": 1,
#   "epistemic authority": 1,
#   "belief-set": 1,
#   "formal \nsystem": 1,
#   "theorem-set": 1,
#   "human-like epistemic agents": 1,
#   "belief maintenance": 1,
#   "human behavior": 1,
#   "multiple-agent": 1,
#   "artificial \nsocial systems": 1,
#   "cooperation": 1,
#   "conditional preference relationships": 1,
#   "artificial societies": 1,
#   "self interest": 1,
#   "group rationality": 1,
#   "average-case identifiability": 1,
#   "average-case \ncontrollability": 1,
#   "enhanced process integration": 1,
#   "multivariable statistics": 1,
#   "high dimension square processes": 1,
#   "nonsquare \nprocesses": 1,
#   "measured variables": 1,
#   "manipulated variables": 1,
#   "process \nidentification": 1,
#   "Monte Carlo simulations": 1,
#   "chemical engineering": 1,
#   "multivariable control \nsystems": 1,
#   "complex biological processes": 1,
#   "robust model-order reduction": 1,
#   "high dimensional \nnonlinear partial differential equation model": 1,
#   "nonlinear distributed \nparameter model": 1,
#   "pilot-scale BNR activated sludge plant": 1,
#   "state-space \nmodel": 1,
#   "singular perturbation approximation balanced truncating \ntechnique": 1,
#   "modelling errors": 1,
#   "controller design": 1,
#   "Hankel singular values": 1,
#   "biological nutrient removal activated sludge processes": 1,
#   "nonlinear \ndifferential equations": 1,
#   "reduced order \nsystems": 1,
#   "singularly perturbed systems": 1,
#   "state-space \nmethods": 1,
#   "water treatment": 1,
#   "decentralized integral controllability": 1,
#   "necessary sufficient conditions": 1,
#   "stable \ndecentralized controllers": 1,
#   "integral action": 1,
#   "closed-loop properties": 1,
#   "stable independent detuning": 1,
#   "control system design": 1,
#   "systematic control \nstructure selection": 1,
#   "steady-state process gain matrix": 1,
#   "real structured \nsingular value": 1,
#   "controller gain realness": 1,
#   "unworkable pairing \nelimination": 1,
#   "Schur complement": 1,
#   "decentralised \ncontrol": 1,
#   "root loci": 1,
#   "large-scale model predictive control": 1,
#   "quadratic programming algorithms": 1,
#   "QPSchur": 1,
#   "cross directional control problems": 1,
#   "paper machines": 1,
#   "object \noriented implementation": 1,
#   "dual space Schur complement algorithm": 1,
#   "simulations": 1,
#   "flexible object oriented construction": 1,
#   "constraint \nhandling": 1,
#   "warm starts": 1,
#   "partial solution": 1,
#   "object-oriented \nprogramming": 1,
#   "quadratic programming": 1,
#   "robust output feedback model predictive control": 1,
#   "off-line linear matrix \ninequalities": 1,
#   "model uncertainty robustness": 1,
#   "robust constrained output \nfeedback MPC algorithm": 1,
#   "polytopic uncertainty": 1,
#   "norm-bound uncertainty": 1,
#   "controller design procedure": 1,
#   "robust constrained state feedback MPC law": 1,
#   "state estimator": 1,
#   "explicit control law sequence": 1,
#   "asymptotically stable invariant ellipsoid": 1,
#   "robust self-tuning PID controller": 1,
#   "preload relay": 1,
#   "robust \nperformance": 1,
#   "chattering phenomenon": 1,
#   "naturally occurring signal": 1,
#   "controller tuning": 1,
#   "controller re-tuning": 1,
#   "relay disabling": 1,
#   "operating \nregime": 1,
#   "continuous tuning": 1,
#   "stability properties": 1,
#   "fluid level control": 1,
#   "spherical tank": 1,
#   "level control": 1,
#   "relay control": 1,
#   "self-organizing context-based approach": 1,
#   "trajectories tracking": 1,
#   "competitive \nlearning": 1,
#   "complex spatiotemporal sequences": 1,
#   "synaptic \nweights": 1,
#   "competitive interlayer connections": 1,
#   "Hebbian intralayer \nconnections": 1,
#   "shared states": 1,
#   "context units": 1,
#   "sequence states": 1,
#   "robot \ntrajectories": 1,
#   "storage abilities": 1,
#   "retrieval \nabilities": 1,
#   "sequence sampling effects": 1,
#   "receptive-field controllers": 1,
#   "evolutionary methods": 1,
#   "real-world \nautonomous agents": 1,
#   "evolution strategies": 1,
#   "simple Braitenberg vehicles": 1,
#   "nonlinear interactions": 1,
#   "complex behavior": 1,
#   "scalable intelligent takeoff controller": 1,
#   "simulated running jointed leg": 1,
#   "neural \ncontrollers": 1,
#   "changing environmental conditions": 1,
#   "scalable \nneurofuzzy controller": 1,
#   "takeoff phase": 1,
#   "running stride": 1,
#   "intelligent \nrobotic control": 1,
#   "cerebellar model arithmetic computers": 1,
#   "legged \nlocomotion": 1,
#   "complete robot dynamics": 1,
#   "multi-dimensional RBF-like neural architecture": 1,
#   "static neural networks": 1,
#   "general system analysis": 1,
#   "fixed grid based neuron placement": 1,
#   "B-spline \npolynomial basis functions": 1,
#   "recursive implementation": 1,
#   "online \nidentification": 1,
#   "dynamic model": 1,
#   "complete 6 joint industrial robot": 1,
#   "neural net architecture": 1,
#   "splines \n(mathematics)": 1,
#   "scalable techniques": 1,
#   "real time robot learning": 1,
#   "locally weighted learning": 1,
#   "training algorithms": 1,
#   "complex phenomena": 1,
#   "autonomous adaptive control": 1,
#   "memory-based learning": 1,
#   "purely incremental \nlearning": 1,
#   "devil-sticking": 1,
#   "pole-balancing": 1,
#   "humanoid robot arm": 1,
#   "inverse-dynamics learning": 1,
#   "statistical neural networks techniques": 1,
#   "nonparametric regression": 1,
#   "real-time \nsystems": 1,
#   "scalable model": 1,
#   "cerebellar adaptive timing": 1,
#   "cerebellar sequencing": 1,
#   "recurrent \nslide and latch model": 1,
#   "neural network theory": 1,
#   "mammalian cerebellum": 1,
#   "granule cell stage": 1,
#   "sparse expansive recoding": 1,
#   "time-varying input \nvector": 1,
#   "distributed representation": 1,
#   "recurrent network": 1,
#   "scalable approach": 1,
#   "cerebellar based control": 1,
#   "nervous system": 1,
#   "computational \ncerebellar models": 1,
#   "light-weight robots": 1,
#   "robot control": 1,
#   "cerebellar model arithmetic \ncomputers": 1,
#   "robot dynamics": 1,
#   "robot \nkinematics": 1,
#   "polymeric microlens fabrication": 1,
#   "micromolding": 1,
#   "hemispherical shape microlens": 1,
#   "size": 1,
#   "optical data storage": 1,
#   "optical communication \nsystems": 1,
#   "polymeric microlenses": 1,
#   "microcompression molding process": 1,
#   "fabrication procedures": 1,
#   "design procedures": 1,
#   "mold insertion": 1,
#   "silicon": 1,
#   "PMMA powder": 1,
#   "molding material": 1,
#   "process parameters": 1,
#   "temperature": 1,
#   "pressure": 1,
#   "micromolding process": 1,
#   "magnification ratio": 1,
#   "300 micron": 1,
#   "microlenses": 1,
#   "optical design techniques": 1,
#   "optical \nfabrication": 1,
#   "optical storage": 1,
#   "disk-type photopolymer high-density holographic storage": 1,
#   "optical setup": 1,
#   "angular \nmultiplexing": 1,
#   "spatial multiplexing": 1,
#   "recording \ndensity": 1,
#   "spatio-angular multiplexing": 1,
#   "limited medium thickness": 1,
#   "optimal \nbeam recording angle": 1,
#   "maximum recording capacity": 1,
#   "maximum density": 1,
#   "holographic storage": 1,
#   "multiplexing": 1,
#   "harmless delays": 1,
#   "Cohen-Grossberg neural networks": 1,
#   "differentiability": 1,
#   "activation functions": 1,
#   "globally \nasymptotic stability": 1,
#   "multiple delays": 1,
#   "Lyapunov functionals": 1,
#   "Razumikhin \ntechnique": 1,
#   "delay-differential systems": 1,
#   "nonlinear dynamical \nsystems": 1,
#   "supersampling multiframe blind deconvolution resolution enhancement": 1,
#   "adaptive \noptics compensated imagery": 1,
#   "low earth orbit satellites": 1,
#   "postprocessing \nmethodology": 1,
#   "undersampled image sequence reconstruction": 1,
#   "randomly \nvarying blur": 1,
#   "sensor sampling resolution": 1,
#   "simulated \nimagery": 1,
#   "Starfire Optical Range telescope": 1,
#   "multiframe blind \ndeconvolution": 1,
#   "ground-based telescope": 1,
#   "spatial sampling": 1,
#   "focal plane \narray elements": 1,
#   "forward stochastic model": 1,
#   "random shifts": 1,
#   "AO-compensated \npoint spread function": 1,
#   "aliasing effects": 1,
#   "sub-Nyquist sampling": 1,
#   "resolution loss": 1,
#   "wide-field-of-view modes": 1,
#   "3.5 m": 1,
#   "adaptive optics": 1,
#   "astronomical techniques": 1,
#   "astronomical telescopes": 1,
#   "astronomy \ncomputing": 1,
#   "optical transfer function": 1,
#   "error probabilities": 1,
#   "optical fiber data buses": 1,
#   "modulation schemes": 1,
#   "Manchester \nbi-phase coding": 1,
#   "receiver sensitivities": 1,
#   "optical \nmodulation": 1,
#   "optical receivers": 1,
#   "bad pixel identification": 1,
#   "principal components analysis": 1,
#   "temporal evolution": 1,
#   "statistical distance": 1,
#   "identification algorithm": 1,
#   "eigenimages": 1,
#   "multinormal distribution": 1,
#   "CCD visible camera": 1,
#   "focal plane \narray": 1,
#   "IR camera": 1,
#   "nonlinear dual-window operator": 1,
#   "nonlinear edge detection \ntechnique": 1,
#   "two-concentric-circular-window operator": 1,
#   "standard gradient": 1,
#   "dual window operator": 1,
#   "zero-crossing points": 1,
#   "difference function": 1,
#   "minimum values": 1,
#   "maximum values": 1,
#   "computational efficiency": 1,
#   "detected \nedges": 1,
#   "Laplacian algorithms": 1,
#   "Gaussian algorithms": 1,
#   "Canny's algorithms": 1,
#   "computational load": 1,
#   "nonlinear processing": 1,
#   "nonlinear optics": 1,
#   "variable-resolution compression": 1,
#   "progressive transmission": 1,
#   "rational system": 1,
#   "moderate risk aversion": 1,
#   "embedded wavelet scheme": 1,
#   "tree structure": 1,
#   "hierarchical pyramid spatial relationship": 1,
#   "transform coefficients": 1,
#   "local spatial region": 1,
#   "successive-approximation quantization": 1,
#   "reconstructed image": 1,
#   "truncation time": 1,
#   "behavioral inconsistency \navoidance": 1,
#   "gambles": 1,
#   "image encoding": 1,
#   "acceptable predictor": 1,
#   "visual \ndistinctness": 1,
#   "digital imagery": 1,
#   "embedded coding": 1,
#   "rate control \noptimization": 1,
#   "decision problem": 1,
#   "progressive transmission utility \nfunctions": 1,
#   "information theoretic measure": 1,
#   "remote sensing images": 1,
#   "electronic delivery": 1,
#   "watermarking techniques": 1,
#   "Earth \nobservation missions": 1,
#   "digital watermarking": 1,
#   "near-lossless watermarking": 1,
#   "digital image distribution": 1,
#   "unsupervised \nimage classification": 1,
#   "copy protection": 1,
#   "coastal zone management": 1,
#   "SPOT images": 1,
#   "environmental impact monitoring": 1,
#   "multitemporal analysis": 1,
#   "land use": 1,
#   "Colombian Caribbean Coast": 1,
#   "anthropogenic activities": 1,
#   "mangrove deforestation": 1,
#   "shrimp farming": 1,
#   "endangered areas": 1,
#   "erosion problems": 1,
#   "water pollution": 1,
#   "satellite images": 1,
#   "human activities": 1,
#   "supervised classification": 1,
#   "sedimentation": 1,
#   "shrimp \nponds": 1,
#   "vectorization": 1,
#   "vector overlay": 1,
#   "aquaculture": 1,
#   "environmental factors": 1,
#   "erosion": 1,
#   "vector \nquantisation": 1,
#   "vegetation mapping": 1,
#   "straight road structure": 1,
#   "urban environments": 1,
#   "IKONOS satellite imagery": 1,
#   "fully \nautomatic technique": 1,
#   "vegetation mask": 1,
#   "texture": 1,
#   "panchromatic IKONOS \ndata": 1,
#   "road pixels": 1,
#   "object-based representation": 1,
#   "higher level reasoning": 1,
#   "individual segment recognition": 1,
#   "road network components": 1,
#   "San Diego": 1,
#   "object-based processing component": 1,
#   "straight-line structured topology": 1,
#   "high-resolution imagery": 1,
#   "large-scale feature extraction": 1,
#   "vectorized \nroad network": 1,
#   "image \nrepresentation": 1,
#   "super-resolution pits readout": 1,
#   "super-resolution reflective film": 1,
#   "Sb \nsuper-resolution reflective layer": 1,
#   "SiN dielectric layer": 1,
#   "numerical \naperture": 1,
#   "Sb thin film thickness": 1,
#   "readout signal": 1,
#   "maximum CNR": 1,
#   "380 nm": 1,
#   "632.8 nm": 1,
#   "28 to 30 nm": 1,
#   "Sb-SiN": 1,
#   "antimony": 1,
#   "optical films": 1,
#   "optical resolving power": 1,
#   "silicon \ncompounds": 1,
#   "optical disk substrate": 1,
#   "transcribability": 1,
#   "birefringence distribution": 1,
#   "insulation layer": 1,
#   "information storage media": 1,
#   "high storage density": 1,
#   "digital video disks": 1,
#   "smaller recording marks": 1,
#   "thinner optical disk \nsubstrates": 1,
#   "replication quality": 1,
#   "land-groove": 1,
#   "pit structure": 1,
#   "fabrication": 1,
#   "stamper": 1,
#   "injection-compression molding": 1,
#   "DVD RAM \nsubstrates": 1,
#   "geometrical properties": 1,
#   "optical properties": 1,
#   "gapwise \nbirefringence distribution": 1,
#   "mold wall": 1,
#   "solidified layer growth \nretardation": 1,
#   "polyimide thermal insulation layer": 1,
#   "birefringence": 1,
#   "optical fabrication": 1,
#   "replica \ntechniques": 1,
#   "substrates": 1,
#   "thermal insulation": 1,
#   "video discs": 1,
#   "automated digital elevation model extraction": 1,
#   "along-track ASTER data": 1,
#   "across-track SPOT stereo images": 1,
#   "stereo satellite images": 1,
#   "ASTER stereo \npair": 1,
#   "SPOT stereo image pair": 1,
#   "radiometric variations": 1,
#   "simultaneous \nalong-track acquisition": 1,
#   "geophysical signal processing": 1,
#   "height measurement": 1,
#   "stereo \nimage processing": 1,
#   "noise-constrained hyperspectral data compression": 1,
#   "transmission requirements": 1,
#   "hyperspectral data sets": 1,
#   "hardware costs": 1,
#   "compression ratios": 1,
#   "lossless compression \ntechniques": 1,
#   "slightly lossy compression algorithm": 1,
#   "noise \nstatistics": 1,
#   "adaptive principal components analysis algorithm": 1,
#   "noise \nlevel": 1,
#   "airborne visible/infrared spectrometer hyperspectral digital \nimagery collection experiment": 1,
#   "AVIRIS HYDICE": 1,
#   "hyperspectral mapper": 1,
#   "HYMAP": 1,
#   "Hyperion datasets": 1,
#   "Gaussian statistics": 1,
#   "infrared spectroscopy": 1,
#   "visible spectroscopy": 1,
#   "satellite image collection optimization": 1,
#   "imaging satellite systems": 1,
#   "multivariable time dynamic optimization system": 1,
#   "graphical user \ninterface": 1,
#   "image collection plan": 1,
#   "long range planning": 1,
#   "daily collection \nscheduling": 1,
#   "Space Imaging IKONOS satellite": 1,
#   "satellite control tasking \nsoftware": 1,
#   "collection commands": 1,
#   "optical two-step modified signed-digit addition": 1,
#   "binary logic gates": 1,
#   "modified \nsigned-digit addition algorithm": 1,
#   "input MSD digits": 1,
#   "flag digits": 1,
#   "binary bits": 1,
#   "addition steps": 1,
#   "low order pair": 1,
#   "carry \npropagation suppression": 1,
#   "two-step addition": 1,
#   "binary coded MSD": 1,
#   "optical \nshadow-casting logic system": 1,
#   "optical logic": 1,
#   "rotating flexible-shaft/multi-flexible-disk system": 1,
#   "eddy-current damper": 1,
#   "rotating flexible-Timoshenko-shaft/flexible-disk coupling system": 1,
#   "assumed-mode method": 1,
#   "virtual work": 1,
#   "Lagrange's equations": 1,
#   "discretized \nequations of motion": 1,
#   "bilinear system": 1,
#   "quadratic feedback control laws": 1,
#   "nonlinear feedback control laws": 1,
#   "optimal feedback control laws": 1,
#   "shear \nvibrations": 1,
#   "flexible vibrations": 1,
#   "optimal \ncontrol": 1,
#   "rotation": 1,
#   "H/sub 2/ optimization": 1,
#   "power spectrum response": 1,
#   "Voigt type dynamic vibration absorber": 1,
#   "three-element type dynamic \nvibration absorbers": 1,
#   "shape memory alloy": 1,
#   "manipulator": 1,
#   "open loop": 1,
#   "closed loop": 1,
#   "variable structure \ncontrol": 1,
#   "control gain switching": 1,
#   "nonlinear control": 1,
#   "nonlinear dynamics": 1,
#   "shape memory effects": 1,
#   "stochastic averaging": 1,
#   "steady state": 1,
#   "random excitations": 1,
#   "feedback stochastic controls": 1,
#   "Ito stochastic differential equation": 1,
#   "Rayleigh approximation": 1,
#   "longitudinal vibration control": 1,
#   "feedback waves": 1,
#   "noncollocated feedback wave \ncontrol": 1,
# ...
#   "linear discrete-time games": 1,
#   "robustly controlled \ninvariance": 1,
#   "two-person dynamic games": 1,
#   "state space": 1,
#   "existence \nconditions": 1,
#   "fault-tolerant controller synthesis": 1,
#   "macroeconomics": 1,
#   "L/sub 2/ model reduction": 1,
#   "finite impulse response models": 1,
#   "output error models": 1,
#   "sliding mode dynamics": 1,
#   "continuous feedback control": 1,
#   "distributed discrete-event \nscheduling": 1,
#   "real-time scheduling": 1,
#   "control theoretic techniques": 1,
#   "distributed manufacturing applications": 1,
#   "highly nonlinear discontinuous \ndynamics": 1,
#   "production demand": 1,
#   "resource capacity": 1,
#   "discrete event systems": 1,
#   "linear parameter varying models": 1,
#   "discrete-time nonlinear \nsystems": 1,
#   "scheduling parameters": 1,
#   "functional dependence": 1,
#   "system \ncoefficients": 1,
#   "linear regression": 1,
#   "least mean square algorithms": 1,
#   "recursive least-squares algorithms": 1,
#   "persistency of excitation \nconditions": 1,
#   "scheduling parameter trajectories": 1,
#   "polynomial interpolation \ninterpretation": 1,
#   "parameter trajectories": 1,
#   "least mean squares methods": 1,
#   "trajectories robustness": 1,
#   "finite time extent": 1,
#   "perturbation bounds": 1,
#   "integral quadratic constraints": 1,
#   "nonconvex \nquadratic optimization problem": 1,
#   "Lagrange relaxation": 1,
#   "robustness \nanalysis": 1,
#   "hybrid systems": 1,
#   "switched dynamical systems": 1,
#   "force tracking control": 1,
#   "constrained mobile manipulators": 1,
#   "parameter uncertainty": 1,
#   "holonomic constraints": 1,
#   "nonholonomic constraints": 1,
#   "adaptive controllers": 1,
#   "reduced dynamic model": 1,
#   "mixed tracking errors": 1,
#   "asymptotic convergence": 1,
#   "force control": 1,
#   "closed-loop persistent identification": 1,
#   "unmodeled dynamics": 1,
#   "linear \ntime-invariant systems": 1,
#   "upper bounds": 1,
#   "lower bounds": 1,
#   "identification \naccuracy": 1,
#   "full rank periodic signals": 1,
#   "stochastic disturbances": 1,
#   "time \ncomplexity": 1,
#   "probing signal selection": 1,
#   "closed-loop model set validation": 1,
#   "stochastic framework": 1,
#   "probabilistic model set \nvalidation": 1,
#   "multi-input multi-output plant": 1,
#   "MIMO plant": 1,
#   "unstructured \nuncertainties": 1,
#   "necessary and sufficient condition": 1,
#   "stabilizing \ncontroller": 1,
#   "closed-loop frequency domain experimental data": 1,
#   "Euclidean \nnorm": 1,
#   "complex vector": 1,
#   "asymptotic statistical properties": 1,
#   "robust \ncontrol": 1,
#   "unstructured uncertainty": 1,
#   "switching controller design": 1,
#   "convex polyhedral Lyapunov functions": 1,
#   "nonlinear \ndiscrete time hybrid systems": 1,
#   "systematic design method": 1,
#   "fundamental parameters": 1,
#   "fundamental parameters \nequations": 1,
#   "nonlinear matrix effects": 1,
#   "x-ray fluorescence analysis": 1,
#   "intensities": 1,
#   "NNFP algorithm": 1,
#   "theoretical correction models": 1,
#   "Lachance-Traill model": 1,
#   "hyperbolic function model": 1,
#   "COLA algorithm": 1,
#   "alloy \nsystem": 1,
#   "Cr": 1,
#   "Fe": 1,
#   "Ni": 1,
#   "complex multivariate system": 1,
#   "chromium alloys": 1,
#   "iron alloys": 1,
#   "nickel alloys": 1,
#   "spectroscopy \ncomputing": 1,
#   "X-ray fluorescence analysis": 1,
#   "railway freight wagon wheelset": 1,
#   "dry friction damping": 1,
#   "linear \ncharacteristics": 1,
#   "lateral dynamics": 1,
#   "stick-slip": 1,
#   "Coulomb law": 1,
#   "bifurcation diagram": 1,
#   "longitudinal component": 1,
#   "tyre modelling": 1,
#   "vehicle dynamics": 1,
#   "standard situations": 1,
#   "limit situations": 1,
#   "tyre \ntorques": 1,
#   "semi-empirical model": 1,
#   "multi-body-systems": 1,
#   "passenger car": 1,
#   "heavy \ntruck": 1,
#   "simulated steady state tyre characteristics": 1,
#   "TMeasy": 1,
#   "Standard \nTyre Interface": 1,
#   "standardized driving manoeuvre": 1,
#   "force": 1,
#   "torque": 1,
#   "stroke dependent damper": 1,
#   "front axle suspension": 1,
#   "multibody system dynamics": 1,
#   "inward deflections": 1,
#   "extreme suspension \ndeflections": 1,
#   "chassis acceleration": 1,
#   "road undulations": 1,
#   "sequential linear \nprogramming": 1,
#   "full-scale model": 1,
#   "truck semi-trailer combination": 1,
#   "incidental road disturbances": 1,
#   "acceleration bound": 1,
#   "vehicle model \nsimulation": 1,
#   "truck comfort": 1,
#   "mechanical variables \ncontrol": 1,
#   "self organizing maps": 1,
#   "down-sampling": 1,
#   "neural network": 1,
#   "human \nface recognition": 1,
#   "visual scene": 1,
#   "skin color detector": 1,
#   "face detecting \nsystem": 1,
#   "merging overlapping detections": 1,
#   "adaptive decentralized stabilization": 1,
#   "uncertain dynamic \nsystems": 1,
#   "interconnected systems": 1,
#   "large-scale \nsystems": 1,
#   "gain-scheduled trajectory tracking controller design": 1,
#   "autonomous vehicles": 1,
#   "gain \nscheduling control theory": 1,
#   "autonomous underwater vehicle": 1,
#   "control laws": 1,
#   "nonlinear equations of motion": 1,
#   "remotely \noperated vehicles": 1,
#   "underwater vehicles": 1,
#   "robust L/sub 2/ disturbance attenuation": 1,
#   "input dynamical \nuncertainty": 1,
#   "L/sub 2/ gain performance": 1,
#   "input-to-state stable property": 1,
#   "design approach": 1,
#   "smooth state feedback \ncontrol law": 1,
#   "nominal system": 1,
#   "FC++": 1,
#   "parametric \npolymorphism": 1,
#   "software \nlibraries": 1,
#   "software applications": 1,
#   "co-operative work support": 1,
#   "collaborative editing": 1,
#   "group \nawareness": 1,
#   "versioning": 1,
#   "messaging": 1,
#   "automated notification": 1,
#   "plug-in \nsoftware components": 1,
#   "collaborative work tools": 1,
#   "BLISS programming language": 1,
#   "machine-oriented language": 1,
#   "portable programming": 1,
#   "system implementation language": 1,
#   "data structure definition": 1,
#   "compile-time \nlanguage": 1,
#   "machine oriented languages": 1,
#   "PLT Scheme": 1,
#   "Component Object Model": 1,
#   "MzCOM": 1,
#   "reuse": 1,
#   "MFC control system technology": 1,
#   "process gas": 1,
#   "surrogate gas": 1,
#   "tuning \nalgorithm": 1,
#   "gas flow": 1,
#   "semiconductor \nfab": 1,
#   "tool technology": 1,
#   "mass flow controller": 1,
#   "N/sub 2/": 1,
#   "interferometric in situ etch sensor": 1,
#   "integrated process control": 1,
#   "polarization": 1,
#   "digital signal processing": 1,
#   "wafer manufacturing environment": 1,
#   "process \npredictive endpoint": 1,
#   "dual damascene trench etch": 1,
#   "spacer etch \napplications": 1,
#   "IC geometry": 1,
#   "complex process sequence integration \nschemes": 1,
#   "upstream deviation compensation": 1,
#   "target specifications": 1,
#   "downstream process sequences": 1,
#   "point-of-use visibility": 1,
#   "work-in-progress \nquality": 1,
#   "scrap reduction": 1,
#   "trench depth control": 1,
#   "interferometry": 1,
#   "integrated etch rate monitor": 1,
#   "etching": 1,
#   "integrated circuit interconnections": 1,
#   "integrated circuit \nmeasurement": 1,
#   "integrated circuit metallisation": 1,
#   "integrated circuit \nyield": 1,
#   "light polarisation": 1,
#   "optical information \nprocessing": 1,
#   "multiple comparison procedures": 1,
#   "population means": 1,
#   "error rate": 1,
#   "single-step \nprocedures": 1,
#   "step-down procedures": 1,
#   "pack-age design": 1,
#   "sampling methods": 1,
#   "analytic functions": 1,
#   "transcendental equations": 1,
#   "Cauchy integral theorem": 1,
#   "complex \nintegration": 1,
#   "root finding": 1,
#   "singularity": 1,
#   "Fourier transform": 1,
#   "mathematics \ncomputing": 1,
#   "breast magnetic resonance imaging": 1,
#   "high spectral spatial resolutions": 1,
#   "healthy \nvolunteers": 1,
#   "edge delineation": 1,
#   "magnetic resonance images": 1,
#   "magnetic resonance imaging data": 1,
#   "contrast medium injection": 1,
#   "water \nresonances": 1,
#   "small voxels": 1,
#   "women": 1,
#   "suspicious lesions": 1,
#   "fat suppression": 1,
#   "turbofan engine": 1,
#   "linear parameter-varying control": 1,
#   "parameter-dependent control \ndesign methods": 1,
#   "state-space descriptions": 1,
#   "time-varying parameters": 1,
#   "linear fractional transformations": 1,
#   "small gain theorem": 1,
#   "performance \nbounds": 1,
#   "robustness bounds": 1,
#   "single quadratic Lyapunov function": 1,
#   "parameter-dependent quadratic Lyapunov function": 1,
#   "Jacobian \nlinearizations": 1,
#   "decoupled command response": 1,
#   "model \nmatching problem": 1,
#   "H/sub infinity / framework": 1,
#   "nonlinear simulations": 1,
#   "very robust designs": 1,
#   "aerospace engines": 1,
#   "time-varying \nsystems": 1,
#   "computerized classification method": 1,
#   "clinical mammograms": 1,
#   "observer study": 1,
#   "breast \ncancer": 1,
#   "computer-aided diagnosis": 1,
#   "independent database": 1,
#   "trained \ncomputer classification scheme": 1,
#   "radiologist observers": 1,
#   "benign masses": 1,
#   "malignant masses": 1,
#   "receiver operating characteristic analysis": 1,
#   "two-tailed P values": 1,
#   "Student t test": 1,
#   "statistical significance": 1,
#   "performances": 1,
#   "average performance": 1,
#   "receiver operating characteristic \ncurve": 1,
#   "diagnostic accuracy": 1,
#   "computer aid": 1,
#   "mammographers": 1,
#   "community \nradiologists": 1,
#   "pulmonary perfusion patterns": 1,
#   "angiographic pulmonary arterial pressure \nmeasurement": 1,
#   "artificial neural network predictions": 1,
#   "pulmonary \nembolism": 1,
#   "pulmonary hypertension": 1,
#   "noninvasive radionuclide perfusion \nscanning": 1,
#   "image analysis": 1,
#   "physiologic information": 1,
#   "visual image \ninspection": 1,
#   "image parameters": 1,
#   "statistical characteristics": 1,
#   "boundary \ncharacteristics": 1,
#   "leave-one-out cross-validation technique": 1,
#   "pulmonary \narterial systolic pressure": 1,
#   "Pearson correlation coefficient": 1,
#   "artificial \nintelligence methods": 1,
#   "quantitative parameters": 1,
#   "perfusion image": 1,
#   "angiography": 1,
#   "radionuclide perfusion images": 1,
#   "normal chest \nradiographs": 1,
#   "29 Pa": 1,
#   "48 Pa": 1,
#   "radioisotope \nimaging": 1,
#   "preterm respiratory mechanics active simulator": 1,
#   "neonatal pulmonary ventilators": 1,
#   "patient active simulator": 1,
#   "healthy newborns": 1,
#   "preterm pathological \ninfants": 1,
#   "apnea times": 1,
#   "autocalibration phase": 1,
#   "respiratory diseases": 1,
#   "ventilatory support": 1,
#   "intensive care equipment": 1,
#   "electronic unit": 1,
#   "pneumatic/mechanical unit": 1,
#   "software control": 1,
#   "double \ncompartment model": 1,
#   "artificial trachea": 1,
#   "pressure transducer": 1,
#   "variable \nclamp resistance": 1,
#   "upper airway resistance": 1,
#   "biomedical transducers": 1,
#   "paediatrics": 1,
#   "patient \ntreatment": 1,
#   "pneumatic control equipment": 1,
#   "pneumodynamics": 1,
#   "six-degree-of-freedom precision motion stage": 1,
#   "piezoelectrically actuated fine motion stage": 1,
#   "3D error compensation": 1,
#   "long-range translation mechanism": 1,
#   "single element piezoelectric linear \ndisplacement actuator": 1,
#   "finite element methods": 1,
#   "resonant frequency": 1,
#   "stage platform": 1,
#   "platform payload": 1,
#   "fundamental mode \nresonance": 1,
#   "1.67 micron": 1,
#   "900 V": 1,
#   "1000 V": 1,
#   "0.93 to -0.93 micron": 1,
#   "162 Hz": 1,
#   "650.0 gm": 1,
#   "error compensation": 1,
#   "micropositioning": 1,
#   "vibration isolation stack": 1,
#   "TAMA300 interferometer": 1,
#   "interferometric \ngravitational wave detectors": 1,
#   "rubber blocks": 1,
#   "multilayer stack": 1,
#   "metal \nblocks": 1,
#   "long-term dimensional stability": 1,
#   "ultrahigh vacuum environment": 1,
#   "operating point": 1,
#   "ground strain": 1,
#   "thermal drift": 1,
#   "thermal actuator": 1,
#   "gas-tight bellows": 1,
#   "rubber outgassing": 1,
#   "vacuum compatibility": 1,
#   "300 m": 1,
#   "10/sup -6/ Pa": 1,
#   "300 Hz": 1,
#   "gravitational wave detectors": 1,
#   "mechanical \nstability": 1,
#   "rubber": 1,
#   "thermal stability": 1,
#   "multichannel scaler": 1,
#   "general statistical analysis": 1,
#   "dynamic light scattering": 1,
#   "correlation spectroscopy": 1,
#   "optical spectroscopic techniques": 1,
#   "photon \nsignal statistical properties": 1,
#   "four channel scaler": 1,
#   "standard high \ntransfer rate parallel computer interface": 1,
#   "interface bus parallel data \ncard": 1,
#   "complex programmable logic device": 1,
#   "standard CPLD ICs": 1,
#   "Pentium \nbased host PC": 1,
#   "windowed Fourier transform": 1,
#   "200 MHz": 1,
#   "200 ns": 1,
#   "light scattering": 1,
#   "photon \ncorrelation spectroscopy": 1,
#   "programmable logic devices": 1,
#   "scaling circuits": 1,
#   "signal processing equipment": 1,
#   "Tsallis difference information": 1,
#   "spontaneous decay": 1,
#   "self-organization": 1,
#   "nonextensive systems": 1,
#   "stimulated transitions": 1,
#   "information measures": 1,
#   "control parameters": 1,
#   "nonextensive statistical mechanics": 1,
#   "phase transformations": 1,
#   "statistical mechanics": 1,
#   "interval-based ABR flow control protocol": 1,
#   "availability bit \nrate service": 1,
#   "ATM networks": 1,
#   "periodic explicit rate feedback": 1,
#   "link \nbandwidth allocation": 1,
#   "buffer space allocation": 1,
#   "maximum throughput": 1,
#   "minimum cell loss": 1,
#   "high resource efficiency": 1,
#   "resource management cell \nsynchronization algorithms": 1,
#   "resource management cell consolidation \nalgorithms": 1,
#   "point-to-multipoint services": 1,
#   "flow control decisions": 1,
#   "loss-free flow control mechanism": 1,
#   "high-speed ABR connections": 1,
#   "fluid \ntraffic model": 1,
#   "signaling": 1,
#   "linear system modeling": 1,
#   "high-speed backbone networking scenarios": 1,
#   "bandwidth allocation": 1,
#   "telecommunication signalling": 1,
#   "communication language": 1,
#   "semantic \nfixing": 1,
#   "semantic space": 1,
#   "social interactions": 1,
#   "protocol execution": 1,
#   "automatic exception handling": 1,
#   "correctness criterion": 1,
#   "multi-agent interactions": 1,
#   "New Jersey African American women writers": 1,
#   "written sources": 1,
#   "personal \ninterviews": 1,
#   "informal conversations": 1,
#   "intellectual output": 1,
#   "oral \nrepository": 1,
#   "collection development": 1,
#   "local writers": 1,
#   "special \ncollections": 1,
#   "literature": 1,
#   "interacting agents": 1,
#   "specifications": 1,
#   "rules of inference": 1,
#   "social commitments": 1,
#   "speech acts": 1,
#   "conversation templates": 1,
#   "ACL": 1,
#   "dynamic system of agents": 1,
#   "system of agents": 1,
#   "agents": 1,
#   "Agent Communication \nLanguages": 1,
#   "dynamic system": 1,
#   "distributed facilitator": 1,
#   "actors": 1,
#   "anonymous \ninteraction protocol": 1,
#   "agent technology": 1,
#   "AI programs": 1,
#   "agent communication language": 1,
#   "inter-agent \ncommunication": 1,
#   "agent societies": 1,
#   "KQML": 1,
#   "conversations": 1,
#   "distributed software engineering": 1,
#   "machine learning": 1,
#   "high temperature-short time pasteurisation process": 1,
#   "dynamic \nmatrix control algorithm": 1,
#   "first order processes": 1,
#   "time delay models": 1,
#   "exogenous variable dependence": 1,
#   "free response \ncalculation": 1,
#   "multiple model information": 1,
#   "nonlinear models": 1,
#   "generalised \nHammerstein model description": 1,
#   "reference tracking": 1,
#   "disturbance \nrejection": 1,
#   "food processing industry": 1,
#   "predictive \ncontrol": 1,
#   "step response": 1,
#   "transfer function matrices": 1,
#   "existence theorems": 1,
#   "nonconvex problems": 1,
#   "variational calculus": 1,
#   "integrant \nconvexity": 1,
#   "polynomial interpolation": 1,
#   "disturbed nodal values": 1,
#   "polynomial \noperators": 1,
#   "economical structural-type functions": 1,
#   "optimisation approach": 1,
#   "explicit analytical form": 1,
#   "natural resources": 1,
#   "pollution control": 1,
#   "optimal strategies": 1,
#   "semi-Markovian inventory system": 1,
#   "system functioning": 1,
#   "optimal nonrandomized Markovian strategy": 1,
#   "optimal strategy": 1,
#   "Euclidean combinatorial optimization problem": 1,
#   "dynamic programming method": 1,
#   "optimal time": 1,
#   "portfolios of securities": 1,
#   "profit maximization": 1,
#   "commodity trading": 1
# }
