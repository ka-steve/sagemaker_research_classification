# %%
import requests
import boto3
import json
import os
import sys
import argparse
import importlib
import transformers
import torch
import pathlib
from IPython.display import display
from sagemaker.huggingface.processing import HuggingFaceProcessor
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import FrameworkProcessor
from sagemaker.sklearn.estimator import SKLearn
from sagemaker.workflow.steps import ProcessingStep
from sagemaker.workflow.pipeline_context import PipelineSession
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker.session import get_execution_role

# Adding ../01_modules or ./01_modules to the system path so that we can load modules from 
# there as well
if '__file__' in globals():
    script_dir = pathlib.Path(__file__).parent.resolve()
else:
    script_dir = pathlib.Path().absolute()
modules_path_in_dev = os.path.abspath(os.path.join(script_dir, '..', '01_modules'))
modules_path_in_prod = os.path.abspath(os.path.join(script_dir, '01_modules'))
if os.path.exists(modules_path_in_dev):
    sys.path.append(modules_path_in_dev)
if os.path.exists(modules_path_in_prod):
    sys.path.append(modules_path_in_prod)


# # Jupyter only reads a local module the first time after 
# # kernel start. Re-running a cell with 
# # "from mymodulename import *" would not change
# # anything, even if the imported module has since changed.
# # As a workaround, we need to directly load the module, 
# # use importlib.reload to reload it and then import * 
import utils
_ = importlib.reload(utils)
import config
_ = importlib.reload(config)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# utils.py loaded: v0.2.12
# utils.py loaded: v0.2.12
# config.py loaded: v0.1
# config.py loaded: v0.1

# %%
import sagemaker
sagemaker.__version__
# Out:
# '2.250.0'

# %%
import torch
torch.__version__
# Out:
# '2.5.1+cu124'

# %%
import transformers
transformers.__version__
# Out:
# '4.49.0'

# %%
removed = """
S3_INPUT_DIR_NAME = '00_test/input'
S3_OUTPUT_DIR_NAME = '00_test/output'

S3_INPUT_DIR_PATH = f'{config.DEFAULT_S3_BUCKET_ROOT}/{S3_INPUT_DIR_NAME}'
S3_OUTPUT_DIR_PATH = f'{config.DEFAULT_S3_BUCKET_ROOT}/{S3_OUTPUT_DIR_NAME}'



#Initialize the HuggingFaceProcessor
hfp = HuggingFaceProcessor(
    role=get_execution_role(), 
    instance_count=1,
    py_version='py311',
    transformers_version=transformers.__version__,
    pytorch_version=torch.__version__.split('+')[0],  # Get the version before any suffix like "+cpu"
    instance_type='ml.g5.2xlarge',
    base_job_name='test-job-002',
    # max_runtime_in_seconds=86400
)

#Run the processing job
hfp.run(
    code='02_ingestion/02_02_ingestion_semanticscholar.py',
    source_dir=os.path.abspath(os.path.join(os.getcwd(), '..')),
    inputs=[
        ProcessingInput(
            input_name='data',
            source=S3_INPUT_DIR_PATH,
            destination=f'{config.DEFAULT_PROCESSING_FILEPATH_PREFIX}/input/data/'
        )
    ],
    outputs=[
        ProcessingOutput(output_name='results', source=f'{config.DEFAULT_PROCESSING_FILEPATH_PREFIX}/output/results/', destination=S3_OUTPUT_DIR_PATH),
        # ProcessingOutput(output_name='train', source='/opt/ml/processing/output/train/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}'),
        # ProcessingOutput(output_name='test', source='/opt/ml/processing/output/test/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}'),
        # ProcessingOutput(output_name='val', source='/opt/ml/processing/output/val/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}')
    ],
    arguments=[
        '--runtype', 'prod',
        '--test-argument-key-01', 'test-argument-value-01', 
        '--test-argument-key-02', 'test-argument-value-02'
    ]
)
"""

# %%
removed = """
S3_INPUT_DIR_NAME = '00_test/input'
S3_OUTPUT_DIR_NAME = '00_test/output'

S3_INPUT_DIR_PATH = f'{config.DEFAULT_S3_BUCKET_ROOT}/{S3_INPUT_DIR_NAME}'
S3_OUTPUT_DIR_PATH = f'{config.DEFAULT_S3_BUCKET_ROOT}/{S3_OUTPUT_DIR_NAME}'

# Using FrameWorkProcessor primarily to be able to use source_dir during the run step, even if we don't need the full flexibility of FrameWorkProcessor or the SKLearn framework
execution_role = get_execution_role()
# pipeline_session = PipelineSession()
print(f'Using execution role: {execution_role}')
sklearn_processor = FrameworkProcessor(
    estimator_cls=SKLearn,
    framework_version='1.2-1', # The newest supported version by sagemaker
    instance_type='ml.t3.medium', # We are just downloading&uploading data, so a small instance is sufficient
    instance_count=1,
    base_job_name='SemanticsScholar-ingestion-FrameworkProcessor-SKlearn-1-7-0',
    # sagemaker_session=pipeline_session,
    role=execution_role
)

step_args = sklearn_processor.run(
    code='02_ingestion/02_02_ingestion_semanticscholar.py',
    source_dir=os.path.abspath(os.path.join(os.getcwd(), '..')),
    inputs=[
        ProcessingInput(
            input_name='data',
            source=S3_INPUT_DIR_PATH,
            destination=f'{config.DEFAULT_PROCESSING_FILEPATH_PREFIX}/input/data/'
        )
    ],
    outputs=[
        ProcessingOutput(output_name='results', source=f'{config.DEFAULT_PROCESSING_FILEPATH_PREFIX}/output/results/', destination=S3_OUTPUT_DIR_PATH),
        # ProcessingOutput(output_name='train', source='/opt/ml/processing/output/train/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}'),
        # ProcessingOutput(output_name='test', source='/opt/ml/processing/output/test/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}'),
        # ProcessingOutput(output_name='val', source='/opt/ml/processing/output/val/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}')
    ],
    arguments=[
        '--runtype', 'prod',
        '--process-files-force-overwrite', 'False',
        '--test-argument-key-01', 'test-argument-value-01', 
        '--test-argument-key-02', 'test-argument-value-02'
    ]
)

# step_process = ProcessingStep(
#     name="ProcessingNameTODO",
#     step_args=step_args
# )

# #Initialize the HuggingFaceProcessor
# hfp = HuggingFaceProcessor(
#     role=get_execution_role(), 
#     instance_count=1,
#     py_version='py311',
#     transformers_version=transformers.__version__,
#     pytorch_version=torch.__version__.split('+')[0],  # Get the version before any suffix like "+cpu"
#     instance_type='ml.g5.2xlarge',
#     base_job_name='test-job-002',
#     # max_runtime_in_seconds=86400
# )

#Run the processing job
# sklearn_processor.run(
#     code='02_ingestion/02_02_ingestion_semanticscholar.py',
#     source_dir=os.path.abspath(os.path.join(os.getcwd(), '..')),
#     inputs=[
#         ProcessingInput(
#             input_name='data',
#             source=S3_INPUT_DIR_PATH,
#             destination=f'{config.DEFAULT_PROCESSING_FILEPATH_PREFIX}/input/data/'
#         )
#     ],
#     outputs=[
#         ProcessingOutput(output_name='results', source=f'{config.DEFAULT_PROCESSING_FILEPATH_PREFIX}/output/results/', destination=S3_OUTPUT_DIR_PATH),
#         # ProcessingOutput(output_name='train', source='/opt/ml/processing/output/train/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}'),
#         # ProcessingOutput(output_name='test', source='/opt/ml/processing/output/test/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}'),
#         # ProcessingOutput(output_name='val', source='/opt/ml/processing/output/val/', destination=f's3://{BUCKET}/{S3_OUTPUT_PATH}')
#     ],
#     arguments=[
#         '--runtype', 'prod',
#         '--test-argument-key-01', 'test-argument-value-01', 
#         '--test-argument-key-02', 'test-argument-value-02'
#     ]
# )

"""

# %%
# Using FrameWorkProcessor primarily to be able to use source_dir during the run step, even if we don't need the full flexibility of FrameWorkProcessor or the SKLearn framework
execution_role = get_execution_role()
sklearn_processor = FrameworkProcessor(
    estimator_cls=SKLearn,
    framework_version='1.2-1', # The newest supported version by sagemaker
    instance_type='ml.t3.medium', # We are just downloading&uploading data, so a small instance is sufficient
    instance_count=1,
    base_job_name='SemanticsScholar-ingestion-FrameworkProcessor-SKlearn-1-7-0',
    role=execution_role
)

step_args = sklearn_processor.run(
    code='02_ingestion/02_02_ingestion_semanticscholar.py',
    source_dir=os.path.abspath(os.path.join(os.getcwd(), '..')),
    inputs=[], # We are not using automatic input-output mapping, instead we handle everything in the script directly on S3
    outputs=[],
    arguments=[
        '--runtype', 'prod',
        '--process-files-force-overwrite', 'False',
    ]
)
# Out:
# Using execution role: arn:aws:iam::762595428873:role/service-role/AmazonSageMaker-ExecutionRole-20250611T204901
# INFO:sagemaker:Creating processing-job with name SemanticsScholar-ingestion-FrameworkPro-2025-08-23-11-46-13-392
# ..............utils.py loaded: v0.2.12
# config.py loaded: v0.1
#  :: :: TIMELOGGER STARTED :: | since_start: 0.00 seconds | since_last: 0.00 seconds ::
# Keys stored in Secrets Managers for the secret "semanticscholar_api_key": ['x-api-key']
#  :: Semanticscholar secret keys fetched | since_start: 0.16 seconds | since_last: 0.16 seconds ::
# Namespace(runtype='prod', process_files_force_overwrite=True, test_argument_key_01='test-argument-value-01', test_argument_key_02='test-argument-value-02')
#  :: testblock 1 | since_start: 0.16 seconds | since_last: 0.00 seconds ::
# ['2022-05-10', '2022-05-17', '2022-05-24', '2022-05-31', '2022-06-07', '2022-06-14', '2022-06-21', '2022-06-28', '2022-07-05', '2022-07-19', '2022-07-28', '2022-08-02', '2022-08-09', '2022-08-16', '2022-08-23', '2022-08-30', '2022-09-06', '2022-09-13', '2022-09-28', '2022-10-05', '2022-10-28', '2022-11-02', '2022-11-11', '2022-11-15', '2022-11-22', '2022-12-02', '2022-12-06', '2022-12-13', '2022-12-20', '2022-12-27', '2023-01-03', '2023-01-10', '2023-01-17', '2023-01-24', '2023-01-31', '2023-02-07', '2023-02-14', '2023-02-21', '2023-02-28', '2023-03-07', '2023-03-14', '2023-03-21', '2023-03-28', '2023-04-06', '2023-04-11', '2023-04-18', '2023-05-09', '2023-05-16', '2023-05-23', '2023-05-30', '2023-06-06', '2023-06-13', '2023-06-20', '2023-07-04', '2023-07-11', '2023-07-25', '2023-08-01', '2023-08-08', '2023-08-15', '2023-08-29', '2023-09-05', '2023-09-12', '2023-09-19', '2023-09-26', '2023-10-10', '2023-10-19', '2023-10-24', '2023-10-31', '2023-11-07', '2023-11-14', '2023-11-21', '2023-11-28', '2023-12-05', '2023-12-12', '2023-12-27', '2024-01-02', '2024-01-24', '2024-01-30', '2024-02-06', '2024-02-20', '2024-02-27', '2024-03-05', '2024-03-12', '2024-03-19', '2024-03-26', '2024-04-02', '2024-04-09', '2024-04-16', '2024-04-23', '2024-04-30', '2024-05-07', '2024-05-14', '2024-05-21', '2024-05-28', '2024-06-04', '2024-06-11', '2024-06-18', '2024-06-25', '2024-07-02', '2024-07-09', '2024-07-16', '2024-07-23', '2024-07-30', '2024-08-06', '2024-08-13', '2024-08-20', '2024-08-27', '2024-09-03', '2024-09-17', '2024-09-24', '2024-10-01', '2024-10-08', '2024-10-15', '2024-10-22', '2024-10-29', '2024-11-05', '2024-11-12', '2024-11-19', '2024-11-26', '2024-12-03', '2024-12-10', '2024-12-17', '2024-12-24', '2024-12-31', '2025-01-07', '2025-01-14', '2025-01-21', '2025-01-28', '2025-02-04', '2025-02-11', '2025-02-18', '2025-02-25', '2025-03-04', '2025-03-11', '2025-03-18', '2025-03-25', '2025-04-01', '2025-04-08', '2025-04-15', '2025-04-22', '2025-05-06', '2025-05-13', '2025-05-20', '2025-05-27', '2025-06-03', '2025-06-10', '2025-06-17', '2025-07-03', '2025-07-08', '2025-07-15', '2025-07-22', '2025-07-29', '2025-08-05', '2025-08-12', '2025-08-19']
# {'name': 'papers', 'description': 'The core attributes of a paper (title, authors, date, etc.).\n200M records in 30 1.5GB files.', 'README': 'Semantic Scholar Academic Graph Datasets\n\nThe "papers" dataset provides core metadata about papers.\n\nSCHEMA\nSee https://api.semanticscholar.org/api-docs/graph#tag/Paper-Data\n\nThis dataset does not contain information about a paper\'s references or citations.\nInstead, join with citingPaperId/citedPaperId from the "citations" dataset.\n\nLICENSE\nThis collection is licensed under ODC-BY. (https://opendatacommons.org/licenses/by/1.0/)\n\nBy downloading this data you acknowledge that you have read and agreed to all the terms in this license.\n\nATTRIBUTION\nWhen using this data in a product or service, or including data in a redistribution, please cite the following paper:\n\nBibTex format:\n@misc{https://doi.org/10.48550/arxiv.2301.10140,\n  title = {The Semantic Scholar Open Data Platform},\n  author = {Kinney, Rodney and Anastasiades, Chloe and Authur, Russell and Beltagy, Iz and Bragg, Jonathan and Buraczynski, Alexandra and Cachola, Isabel and Candra, Stefan and Chandrasekhar, Yoganand and Cohan, Arman and Crawford, Miles and Downey, Doug and Dunkelberger, Jason and Etzioni, Oren and Evans, Rob and Feldman, Sergey and Gorney, Joseph and Graham, David and Hu, Fangzhou and Huff, Regan and King, Daniel and Kohlmeier, Sebastian and Kuehl, Bailey and Langan, Michael and Lin, Daniel and Liu, Haokun and Lo, Kyle and Lochner, Jaron and MacMillan, Kelsey and Murray, Tyler and Newell, Chris and Rao, Smita and Rohatgi, Shaurya and Sayre, Paul and Shen, Zejiang and Singh, Amanpreet and Soldaini, Luca and Subramanian, Shivashankar and Tanaka, Amber and Wade, Alex D. and Wagner, Linda and Wang, Lucy Lu and Wilhelm, Chris and Wu, Caroline and Yang, Jiangjiang and Zamarron, Angele and Van Zuylen, Madeleine and Weld, Daniel S.},\n  publisher = {arXiv},\n  year = {2023},\n  doi = {10.48550/ARXIV.2301.10140},\n  url = {https://arxiv.org/abs/2301.10140},\n}\n\n\n'}
# {'name': 's2orc', 'description': 'Full-body paper text parsed from open-access PDFs. Identifies structural elements such as paragraphs, sections, and bibliography entries.\n10M records in 30 4GB files.', 'README': 'Semantic Scholar Academic Graph Datasets\n\nThe "s2orc" dataset contains parsed full-body text from selected papers.\n\nA subset of this data was previously released (in a different format) as S2ORC https://github.com/allenai/s2orc\n\nThe body text is parsed from PDF documents using Grobid, documented at https://grobid.readthedocs.io.\nIts output is converted from XML into a single string with a set of annotation spans.\n\nSCHEMA\n - externalIds: IDs of this paper in different catalogs\n - content:\n   - source:\n\t   - pdfUrls: URLs to the PDF\n\t   - oaInfo: license/url/status information from Unpaywall\n   - text: Full body text as a single string\n   - annotations: Annotated spans of the full body text\n\n\nLICENSE\nThis collection is licensed under ODC-BY. (https://opendatacommons.org/licenses/by/1.0/)\n\nBy downloading this data you acknowledge that you have read and agreed to all the terms in this license.\n\nATTRIBUTION\nWhen using this data in a product or service, or including data in a redistribution, please cite the following paper:\n\n@inproceedings{lo-wang-2020-s2orc,\n    title = "{S}2{ORC}: The Semantic Scholar Open Research Corpus",\n    author = "Lo, Kyle  and Wang, Lucy Lu  and Neumann, Mark  and Kinney, Rodney  and Weld, Daniel",\n    booktitle = "Proceedings of the 58th Annual Meeting of the Association for Computational Linguistics",\n    month = jul,\n    year = "2020",\n    address = "Online",\n    publisher = "Association for Computational Linguistics",\n    url = "https://www.aclweb.org/anthology/2020.acl-main.447",\n    doi = "10.18653/v1/2020.acl-main.447",\n    pages = "4969--4983"\n}\n'}
# SEMANTICSCHOLAR_LATEST_RELEASE_ID: 2025-08-19
#  :: Semanticscholar latest release ID fetched | since_start: 1.33 seconds | since_last: 1.17 seconds ::
# Fetching dataset download URLs from: https://api.semanticscholar.org/datasets/v1/release/2025-08-12/dataset/s2orc with headers: {'x-api-key': 'uHDeGK1oTg65iSV723vbv9HYA4oWKiXeaPR8Kv8I'}
# len(s2orc_file_urls) 509
#  :: Semanticscholar URLS downloaded | since_start: 3.07 seconds | since_last: 1.74 seconds ::
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_008f7a4a-4961-4b86-aae9-86a2b9577d73.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=kw5dsD7Tc89aouNTHLzDYUMB2Gk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part0.jsonl.gz
# Uploading s2orc-part0.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part0.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_00d6d08b-80f2-4099-9f9d-c9a576bbaa39.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=ncms0gLArFe28hMyZIJMnXfelAI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part1.jsonl.gz
# Uploading s2orc-part1.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part1.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0125774f-e59e-4c78-964d-3e0bf04a9d61.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=Y78b18ZnnrXijM1vb9Mg%2Foix7pY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part2.jsonl.gz
# Uploading s2orc-part2.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part2.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_018f5335-f372-4bea-8203-b3ad2637d9b4.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=LHwSDlBzLfZoz8SGIO5Jn03pdVU%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part3.jsonl.gz
# Uploading s2orc-part3.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part3.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_02948dc3-3fb8-4c91-9344-2b44918fced8.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=8xpwIBtmwjM52T7%2BQb%2F4LZQ2XZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part4.jsonl.gz
# Uploading s2orc-part4.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part4.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_040eea89-c7de-4ee0-a1ee-f478a547e9c5.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=0g0jtMJjhKRXqBuRlD2UVuyt13g%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part5.jsonl.gz
# Uploading s2orc-part5.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part5.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_063fcd47-f77d-4a45-8cdb-537f3a26c083.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=6d5yp7wWbFu5bZ5Ar1MFi8v8Bug%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part6.jsonl.gz
# Uploading s2orc-part6.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part6.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_06b61c96-bca1-45b0-9cde-8eb30f387798.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=YB5z0eDh3WcYlwW4xS%2F%2FT5u2bsU%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part7.jsonl.gz
# Uploading s2orc-part7.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part7.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_090e5a86-685b-41ba-8a5d-b4d4be1acb7a.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=3PrV4MPcsXV0DJUZuDUxJLPPchM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part8.jsonl.gz
# Uploading s2orc-part8.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part8.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0b62a426-bf7e-45c7-a269-67457e3007cd.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=yE7RbM%2FPiiYB9HNYQsCjg8jSzXY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part9.jsonl.gz
# Uploading s2orc-part9.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part9.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0c351eec-8a33-4e95-b1cf-a35aaed4cc96.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=edElp9jc%2FAVJTLSPQGt5V7b9Fd4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part10.jsonl.gz
# Uploading s2orc-part10.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part10.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0e20e499-4a04-413e-859c-4a37408d79cc.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=O%2FtOBMT%2B2ffime2VVWz94EmBG5A%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part11.jsonl.gz
# Uploading s2orc-part11.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part11.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0eaee3bd-92fc-4c13-bd77-39cd174dc30c.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=u9N7BS08%2B%2B5gxVyPEtsrIdyac5I%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part12.jsonl.gz
# Uploading s2orc-part12.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part12.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0ed33427-064d-4373-87f4-0750dc9d9ffc.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=j%2FHyWdiM%2F7sWNndTUxPPsv8Owsk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part13.jsonl.gz
# Uploading s2orc-part13.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part13.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0f3a1b6c-c37c-4b3b-b71e-4c4c46354db3.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=yVHzZ1icHgl9jhWFWAbg6x2ZiLY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part14.jsonl.gz
# Uploading s2orc-part14.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part14.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_0fdc4b55-d15f-4d39-b38b-8139deafbd75.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=T6NaYc2kEVUCP6rwAgLJwl%2Ft3iY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part15.jsonl.gz
# Uploading s2orc-part15.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part15.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_1045b48d-0dc4-4af7-b425-ccca1cf7286a.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=B9NyDDpBuAar5JQgbWsE5SE3Px8%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part16.jsonl.gz
# Uploading s2orc-part16.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part16.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_12e223e1-af46-4300-b8bc-b015a0bde6b6.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=3R4otDFPfFeGbaukc4yKPXKOYI8%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part17.jsonl.gz
# Uploading s2orc-part17.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part17.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_134527ca-1c72-4f32-8c3e-bf41223c8198.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=%2BjOe6Bcv7P9LcnRNULP49lk2xKk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part18.jsonl.gz
# Uploading s2orc-part18.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part18.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_13fefcf3-2d3c-46fc-a7d9-d2589abb4d45.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=p0Z6ZPkev2wEuziUjGtX%2Fr9fsPI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part19.jsonl.gz
# Uploading s2orc-part19.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part19.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_14042c86-4503-4f2b-971d-114d8f5068d1.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=HVOpotsjqLsOIO6b6rsBWc8BZ9Y%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part20.jsonl.gz
# Uploading s2orc-part20.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part20.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_140be8a5-2c20-4e02-8f13-d6a8dc4cba57.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=WSknDqE3GJcnmVhOWyywi646vts%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part21.jsonl.gz
# Uploading s2orc-part21.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part21.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_159921de-e4dd-444e-80c8-8f58ba05c282.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=2O%2FtaGvRR7dMCIML7xvPuIAXCIA%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part22.jsonl.gz
# Uploading s2orc-part22.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part22.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_163f127c-bfed-4d57-85cf-eebfc335fee9.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=xuw18Wh6u6yoq1p4JnS%2FGkKMdGI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554510...
# File downloaded: s2orc-part23.jsonl.gz
# Uploading s2orc-part23.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part23.jsonl.gz
# ...
# File downloaded: s2orc-part58.jsonl.gz
# Uploading s2orc-part58.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part58.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3b833c91-cdc0-4bfe-90ed-53c1171a94f5.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=BBydo3S2qPaIDWooktakmLoBqfA%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part59.jsonl.gz
# Uploading s2orc-part59.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part59.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3bea4735-962a-4a3f-b0da-56d688c43c42.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=inH18EFGwJiZTzv4J13Ektl1s9w%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part60.jsonl.gz
# Uploading s2orc-part60.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part60.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3c5ec31c-6445-44af-ba76-713edaf81d3d.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=w67EBPMPytUTEEla6ZGlnGt8Q7g%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part61.jsonl.gz
# Uploading s2orc-part61.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part61.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3cb4b141-9424-407a-8458-2d4517b6255a.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=DyEf6PTCAZW%2FxHDykezRtQ2pCDg%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part62.jsonl.gz
# Uploading s2orc-part62.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part62.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3d551098-2f04-4d3d-a051-fc8a46342eb5.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=uvnIKx88uHQsFHJjzrsruG6dtQ4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part63.jsonl.gz
# Uploading s2orc-part63.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part63.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3f2b1c03-7533-4439-96b2-ac3f6069263a.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=0nGnH%2FEK6nl5AfgKqll5k5mWGcc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part64.jsonl.gz
# Uploading s2orc-part64.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part64.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3f66c86c-11fc-4000-9595-8e940c491bfb.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=ZvJip1T%2BJbza5rPH9lxMrE8ShlE%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part65.jsonl.gz
# Uploading s2orc-part65.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part65.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3f997dc0-152d-4bd2-861e-49f59276c0f1.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=MMyDKbnTJ5FWwgKUUmnAkHbFa4M%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...
# File downloaded: s2orc-part66.jsonl.gz
# Uploading s2orc-part66.jsonl.gz to S3 bucket sagemaker-research-methodology-extraction...
# File uploaded to S3: s3://sagemaker-research-methodology-extraction/01_data/01_raw/semanticscholar/s2orc/s2orc-part66.jsonl.gz
# Downloading file from https://ai2-s2ag.s3.amazonaws.com/staging/2025-08-12/s2orc/20250815_113147_00039_6wjwx_3fafeb53-7716-4ffe-b2c3-54fb3e50f86d.gz?AWSAccessKeyId=ASIA5BJLZJPW6AH7CFY5&Signature=jEjhyG%2FnfOCyxGQR0vlX7yhQPzs%3D&x-amz-security-token=IQoJb3JpZ2luX2VjENL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJIMEYCIQDTurA1bXtiz5fS4dCB0lMT7S18n%2BEFev7RRgL35EeOVwIhANLk8iFFOxT9U6NzG3annJxk6CaQAa%2F%2BXpkr%2FcyZPfJXKv8DCCsQABoMODk2MTI5Mzg3NTAxIgw0GX8iBRlxJqp0UT4q3APYQRc%2FIALJ1h%2FRGMefidZu0r5qKmpenvNezlLezQKX2s4BSmUKFKabM1VekitsmGTMpjVbPmBpX0aIbSvRNgZWkPo3WHYTzYw7QEMCheXbxgmQlPtY0cUi2bVa0gdfaK%2FBgqUv%2BKOV1lj8UX2mjlBC6dSSQK3%2B7qdhySJ%2BiDace5LwK8N%2BhixOSzvMgHjPJcwx%2Bws3QurAchS%2FjMuek8%2BVA9N187cg%2BevsJO8jQ4zzJcbt9C4npgeL8Oh%2Bt0VAJBJbCS1KX54jYBcHovbbxjHkudHalzWfZOBIRfCnQnvZOJCG015tg6sWdd%2FmjrTo%2FS8jv6cor5q%2FQL%2B0qqC%2FcrMGU9ekOqji1at1oKppVBXeNMBZOG5wcdSmIhqOcmLzY%2BXqPSjn5Nvozq%2BwtAqW8mu%2BBdkm7NY3iWWNiC1NceQxiCRnZQ4p0w%2FMMZKqJVPQcFlHWtkh%2BEYHosZP0pw4WStvv9x2kp2ynMT8hyPozsx5aSM%2B%2Fn%2B7po2FFcybw5ZgNVoKV1X1yK3PG84MbBsXOqnHbUUXUCa2I9BuW4I1g9d4wFn4aqvVSFjnXSaPSQ42VSNlgx2hBCoonyIwKiPln4v3ULSpPmRl2dnvXH%2BxevXX5jSvO5eOmpsJzuTCLDDlpabFBjqkAcrJsl0QIo7hKG9jKpRAWgSY8Uk9FC%2FPhIgbHf0DfgbURFVTchOhrvuGHb%2Fh4P0bufsfWgYg7NJw1iKWbvgqk5zad6W2DozJ%2BqjyjQqOGxUIFEDzJLq4pi%2FbOmrFuH2paTa7Q%2F6CUroKc%2FsNyWoEtNFDh7zNrZUd%2BC1VWTKBqnw5dJXyk2cVv%2F8MSykb6elhM4SExLRkrDdR3ryWK8i5wABOkOG5&Expires=1756554511...

# %%
# Using FrameWorkProcessor primarily to be able to use source_dir during the run step, even if we don't need the full flexibility of FrameWorkProcessor or the SKLearn framework
execution_role = get_execution_role()
sklearn_processor = FrameworkProcessor(
    estimator_cls=SKLearn,
    framework_version='1.2-1', # The newest supported version by sagemaker
    instance_type='ml.t3.medium', # We are just executing an S3 data transfer, so a small instance is sufficient
    instance_count=1,
    base_job_name='OpenAlex-ingestion',
    role=execution_role
)

step_args = sklearn_processor.run(
    code='02_ingestion/02_03_ingestion_openalex.py',
    source_dir=os.path.abspath(os.path.join(os.getcwd(), '..')),
    inputs=[], # We are not using automatic input-output mapping, instead we handle everything in the script directly on S3
    outputs=[],
    arguments=[
        '--runtype', 'prod',
    ]
)
# Out:
# INFO:sagemaker.processing:Uploaded /home/sagemaker-user/research_methodology_extraction/src to s3://sagemaker-eu-west-2-762595428873/OpenAlex-ingestion-FrameworkProcessor-S-2025-08-23-19-39-02-404/source/sourcedir.tar.gz
# INFO:sagemaker.processing:runproc.sh uploaded to s3://sagemaker-eu-west-2-762595428873/OpenAlex-ingestion-FrameworkProcessor-S-2025-08-23-19-39-02-404/source/runproc.sh
# INFO:sagemaker:Creating processing-job with name OpenAlex-ingestion-FrameworkProcessor-S-2025-08-23-19-39-02-404
# .................utils.py loaded: v0.2.12
# config.py loaded: v0.1
#  :: :: TIMELOGGER STARTED :: | since_start: 0.00 seconds | since_last: 0.00 seconds ::
# Namespace(runtype='prod')
#  :: Processed arguments | since_start: 0.00 seconds | since_last: 0.00 seconds ::
#  :: OpenAlex files synced to target bucket | since_start: 0.00 seconds | since_last: 0.00 seconds ::
# Starting Glue Crawler: crawler_01_raw_openalex_...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ is still running...
# Glue Crawler crawler_01_raw_openalex_ has completed.
#  :: OpenAlex glue crawl done | since_start: 3.0 minutes, 11.91 seconds | since_last: 3.0 minutes, 11.91 seconds ::
#  :: DONE | since_start: 3.0 minutes, 11.91 seconds | since_last: 0.00 seconds ::
