# %%
import requests
import boto3
import json
import os
import sys
import argparse
import importlib
import transformers
import torch
import pathlib
import awswrangler as wr
import plotly.express as px
import plotly.io as pio
from IPython.display import display
from sagemaker.huggingface.processing import HuggingFaceProcessor
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import FrameworkProcessor
from sagemaker.sklearn.estimator import SKLearn
from sagemaker.workflow.steps import ProcessingStep
from sagemaker.workflow.pipeline_context import PipelineSession
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker.session import get_execution_role


# Adding ../01_modules or ./01_modules to the system path so that we can load modules from 
# there as well
if '__file__' in globals():
    script_dir = pathlib.Path(__file__).parent.resolve()
else:
    script_dir = pathlib.Path().absolute()
modules_path_in_dev = os.path.abspath(os.path.join(script_dir, '..', '01_modules'))
modules_path_in_prod = os.path.abspath(os.path.join(script_dir, '01_modules'))
if os.path.exists(modules_path_in_dev):
    sys.path.append(modules_path_in_dev)
if os.path.exists(modules_path_in_prod):
    sys.path.append(modules_path_in_prod)


# # Jupyter only reads a local module the first time after 
# # kernel start. Re-running a cell with 
# # "from mymodulename import *" would not change
# # anything, even if the imported module has since changed.
# # As a workaround, we need to directly load the module, 
# # use importlib.reload to reload it and then import * 
import utils
_ = importlib.reload(utils)
import config
_ = importlib.reload(config)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# config.py loaded: v0.1
# utils.py loaded: v0.2.12
# utils.py loaded: v0.2.12
# config.py loaded: v0.1

# %%
pio.renderers.default = 'iframe'
pio.get_chrome()
utils.pd_set_options(cols=500)

# %%
wr.athena.read_sql_query("""
    SELECT 
        COUNT(*) AS number_of_papers,
        COUNT(DISTINCT subfield_index) AS number_of_subfields,
        COUNT(DISTINCT topic_index) AS number_of_topics
    FROM
        unified_works
""", '03_core')
# Out:
#    number_of_papers  number_of_subfields  number_of_topics
# 0            388735                   11               302

# %%
df_subfield_stat = wr.athena.read_sql_query("""
SELECT 
    subfield_index, 
    subfield_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM unified_works), 2) AS percent_of_papers
FROM
    unified_works
GROUP BY
    subfield_index, subfield_display_name
ORDER BY
    number_of_papers DESC
 """, '03_core')
df_subfield_stat.head()
# Out:
#    subfield_index                    subfield_display_name  number_of_papers  percent_of_papers
# 0               0                  Artificial Intelligence            148548              38.21
# 1               1  Computer Vision and Pattern Recognition             63978              16.46
# 2               2                      Information Systems             53891              13.86
# 3               3     Computer Networks and Communications             42035              10.81
# 4               4     Computational Theory and Mathematics             34092               8.77

# %%
fig = px.histogram(
    df_subfield_stat,
    x='subfield_display_name',
    y='number_of_papers',
    title='Number of papers per Subfield'
)
fig.update_layout(xaxis_title='')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_6.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_topic_stat = wr.athena.read_sql_query("""
SELECT 
    topic_index, 
    topic_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM unified_works), 2) AS percent_of_papers
FROM
    unified_works
GROUP BY
    topic_index, topic_display_name
ORDER BY
    number_of_papers DESC
 """, '03_core')
df_topic_stat.head(1000)
# Out:
#      topic_index                                            topic_display_name  number_of_papers  percent_of_papers
# 0              0                                                Topic Modeling             18594               4.78
# 1              1                        Natural Language Processing Techniques             14575               3.75
# 2              2                          Computational Drug Discovery Methods             11454               2.95
# 3              3                          Quantum Information and Cryptography              8393               2.16
# 4              4                 Quantum Computing Algorithms and Architecture              7213               1.86
# 5              5               Blockchain Technology Applications and Security              6448               1.66
# 6              6                          Advanced Neural Network Applications              6081               1.56
# 7              7                                        AI in cancer detection              4854               1.25
# 8              8                              Neural Networks and Applications              4523               1.16
# 9              9                                    IoT and Edge/Fog Computing              4473               1.15
# 10            10                      Network Security and Intrusion Detection              4352               1.12
# 11            11                       Privacy-Preserving Technologies in Data              4263               1.10
# 12            12                              Robotic Path Planning Algorithms              4024               1.04
# 13            13                                 Online Learning and Analytics              3917               1.01
# 14            15                     Energy Efficient Wireless Sensor Networks              3802               0.98
# 15            16                         Sentiment Analysis and Opinion Mining              3766               0.97
# 16            14                 Anomaly Detection Techniques and Applications              3751               0.96
# 17            17                      Virtual Reality Applications and Impacts              3432               0.88
# 18            20                             Educational Methods and Media Use              3421               0.88
# 19            18                       Video Surveillance and Tracking Methods              3408               0.88
# 20            19                      Multimodal Machine Learning Applications              3402               0.88
# 21            22                                   Advanced Vision and Imaging              3227               0.83
# 22            21                                 Software Engineering Research              3190               0.82
# 23            23                    Adversarial Robustness in Machine Learning              3101               0.80
# 24            24                       Domain Adaptation and Few-Shot Learning              2893               0.74
# 25            25                                   Speech and Audio Processing              2850               0.73
# 26            26                       Cloud Computing and Resource Management              2797               0.72
# 27            27                                    Music and Audio Processing              2773               0.71
# 28            28                    Context-Aware Activity Recognition Systems              2772               0.71
# 29            29                            Recommender Systems and Techniques              2759               0.71
# 30            32                                   Semantic Web and Ontologies              2720               0.70
# 31            31                Metaheuristic Optimization Algorithms Research              2717               0.70
# 32            33                              Speech Recognition and Synthesis              2705               0.70
# 33            30                             Geochemistry and Geologic Mapping              2697               0.69
# 34            35                 Advanced Image and Video Retrieval Techniques              2694               0.69
# 35            34                 Advanced Mathematical Modeling in Engineering              2520               0.65
# 36            36                                Machine Learning in Healthcare              2510               0.65
# 37            37                             Human Pose and Action Recognition              2497               0.64
# 38            39                       Hate Speech and Cyberbullying Detection              2433               0.63
# 39            40                         Advanced Malware Detection Techniques              2354               0.61
# 40            41                            Reinforcement Learning in Robotics              2311               0.59
# 41            42                                Advanced Graph Neural Networks              2290               0.59
# 42            44                            Image and Signal Denoising Methods              2231               0.57
# 43            38                                Advanced Graph Theory Research              2220               0.57
# 44            46                                Cryptography and Data Security              2213               0.57
# 45            45                    Distributed and Parallel Computing Systems              2210               0.57
# 46            48                        Educational Innovations and Challenges              2187               0.56
# 47            43                      Nonlinear Dynamics and Pattern Formation              2152               0.55
# 48            49           Generative Adversarial Networks and Image Synthesis              2137               0.55
# 49            47                     Explainable Artificial Intelligence (XAI)              2134               0.55
# 50            50                                Augmented Reality Applications              2067               0.53
# 51            51            Advanced Steganography and Watermarking Techniques              2056               0.53
# 52            53                           Chaos-based Image/Signal Encryption              2042               0.53
# 53            54                       Neural Networks and Reservoir Computing              1998               0.51
# 54            52                             Solar Radiation and Photovoltaics              1984               0.51
# 55            55                Parallel Computing and Optimization Techniques              1967               0.51
# 56            56                                 Face recognition and analysis              1929               0.50
# 57            58                          Advanced Image Processing Techniques              1922               0.49
# 58            60                         Optimization and Variational Analysis              1910               0.49
# 59            59                            Research Data Management Practices              1909               0.49
# 60            57                         Medical Image Segmentation Techniques              1899               0.49
# 61            61                       Distributed Control Multi-Agent Systems              1879               0.48
# 62            62                              Data Visualization and Analytics              1870               0.48
# 63            63                              Software-Defined Networks and 5G              1867               0.48
# 64            64                                Data Management and Algorithms              1847               0.48
# 65            66                                  Digital Media and Visual Art              1815               0.47
# 66            65                                Formal Methods in Verification              1800               0.46
# 67            67                          Time Series Analysis and Forecasting              1743               0.45
# 68            69                                  Image Enhancement Techniques              1738               0.45
# 69            68               Optical measurement and interference techniques              1738               0.45
# 70            71                              Hand Gesture Recognition Systems              1671               0.43
# 71            72                          Logic, programming, and type systems              1656               0.43
# 72            73                      Machine Learning and Data Classification              1649               0.42
# 73            70                                  Matrix Theory and Algorithms              1634               0.42
# 74            74                               Face and Expression Recognition              1629               0.42
# 75            77                                  Mobile Learning in Education              1628               0.42
# 76            75                       Handwritten Text Recognition Techniques              1612               0.41
# 77            76                           Bayesian Methods and Mixture Models              1594               0.41
# 78            78                                Information and Cyber Security              1591               0.41
# 79            79                               Algorithms and Data Compression              1571               0.40
# 80            82                             Teaching and Learning Programming              1540               0.40
# 81            80                        Bayesian Modeling and Causal Inference              1529               0.39
# 82            81                       Innovative Human-Technology Interaction              1525               0.39
# 83            83            Target Tracking and Data Fusion in Sensor Networks              1523               0.39
# 84            84                             Advanced Text Analysis Techniques              1520               0.39
# 85            86                        English Language Learning and Teaching              1517               0.39
# 86            85                        Gaze Tracking and Assistive Technology              1504               0.39
# 87            89                                   Speech and dialogue systems              1466               0.38
# 88            87              Advanced Multi-Objective Optimization Algorithms              1440               0.37
# 89            92                 Image Retrieval and Classification Techniques              1440               0.37
# 90            91                         Biometric Identification and Security              1439               0.37
# 91            88                                Coding theory and cryptography              1415               0.36
# 92            93                     Software Testing and Debugging Techniques              1409               0.36
# 93            90                       Topological and Geometric Data Analysis              1391               0.36
# 94            95                  Cooperative Communication and Network Coding              1347               0.35
# 95            98                   Educational Methods and Teacher Development              1338               0.34
# 96            97                       Organizational and Employee Performance              1329               0.34
# 97            96                            Advanced Data Storage Technologies              1325               0.34
# 98            94                 Software Engineering Techniques and Practices              1325               0.34
# 99           100                                        Mobile Ad Hoc Networks              1323               0.34
# 100           99                     Imbalanced Data Classification Techniques              1314               0.34
# 101          102                Computer Graphics and Visualization Techniques              1260               0.32
# 102          101                               Logic, Reasoning, and Knowledge              1258               0.32
# 103          103                       Visual Attention and Saliency Detection              1233               0.32
# 104          105                                  Caching and Content Delivery              1233               0.32
# 105          104                            Blind Source Separation Techniques              1229               0.32
# 106          107                                    AI in Service Interactions              1211               0.31
# 107          108                       Data Mining Algorithms and Applications              1200               0.31
# 108          109                           Educational Technology and Pedagogy              1198               0.31
# 109          106                           Computability, Logic, AI Algorithms              1197               0.31
# 110          111                    Cryptographic Implementations and Security              1163               0.30
# 111          110                               Machine Learning and Algorithms              1157               0.30
# 112          113                                    Rough Sets and Fuzzy Logic              1122               0.29
# 113          114                 Text and Document Classification Technologies              1108               0.29
# 114          116                            Image and Video Quality Assessment              1090               0.28
# 115          115                                   Spam and Phishing Detection              1078               0.28
# 116          112                                semigroups and automata theory              1075               0.28
# 117          118                               Economic Growth and Development              1056               0.27
# 118          117                   Software System Performance and Reliability              1051               0.27
# 119          120                 Cognitive Radio Networks and Spectrum Sensing              1050               0.27
# 120          123                 Neural Networks Stability and Synchronization              1035               0.27
# 121          119                            Digital Imaging for Blood Diseases              1031               0.27
# 122          121                                    Advanced Algebra and Logic              1005               0.26
# 123          125                       Distributed systems and fault tolerance              1005               0.26
# 124          124                      Evolutionary Algorithms and Applications               997               0.26
# 125          126                Service-Oriented Architecture and Web Services               996               0.26
# 126          122                    Computational Geometry and Mesh Generation               984               0.25
# 127          127                                      Machine Learning and ELM               970               0.25
# 128          129                      User Authentication and Security Systems               949               0.24
# 129          130                              Digital Media Forensic Detection               945               0.24
# 130          128                           Complexity and Algorithms in Graphs               944               0.24
# 131          132                                 Digital literacy in education               908               0.23
# 132          133                 Internet Traffic Analysis and Secure E-voting               896               0.23
# 133          135                              Video Analysis and Summarization               891               0.23
# 134          136                 Data Mining and Machine Learning Applications               889               0.23
# 135          131                     Gaussian Processes and Bayesian Inference               884               0.23
# 136          134                 Computational Physics and Python Applications               876               0.23
# 137          139                            Music Technology and Sound Studies               868               0.22
# 138          138                        Image Processing and 3D Reconstruction               863               0.22
# 139          142                          Education and Learning Interventions               860               0.22
# 140          137                                 Data Stream Mining Techniques               860               0.22
# 141          141                        Security and Verification in Computing               858               0.22
# 142          144                          Advanced Data Compression Techniques               848               0.22
# 143          143                         Mobile Crowdsensing and Crowdsourcing               846               0.22
# 144          140                       Advanced Clustering Algorithms Research               846               0.22
# 145          147                     Wireless Signal Modulation Classification               836               0.22
# 146          146                           Multi-Agent Systems and Negotiation               828               0.21
# 147          150                                 Cloud Data Security Solutions               826               0.21
# 148          149                            Digital Communication and Language               826               0.21
# 149          152                     Sensor Technology and Measurement Systems               818               0.21
# 150          148                              COVID-19 Digital Contact Tracing               808               0.21
# 151          154            Intelligent Tutoring Systems and Adaptive Learning               804               0.21
# 152          155                    Direction-of-Arrival Estimation Techniques               804               0.21
# 153          153                               Fuzzy Logic and Control Systems               801               0.21
# 154          151                                 Cognitive Science and Mapping               801               0.21
# 155          156                                 Open Education and E-Learning               797               0.21
# 156          145                         Graph Labeling and Dimension Problems               794               0.20
# 157          159                                Edcuational Technology Systems               784               0.20
# 158          158                           Text Readability and Simplification               781               0.20
# 159          157                             Seismology and Earthquake Studies               774               0.20
# 160          160                       Advanced Technologies in Various Fields               772               0.20
# 161          162                     Opportunistic and Delay-Tolerant Networks               767               0.20
# 162          164    Physical Unclonable Functions (PUFs) and Hardware Security               755               0.19
# 163          163                              Artificial Intelligence in Games               755               0.19
# 164          168                         Educational Technology and Assessment               749               0.19
# 165          170               Blockchain Technology in Education and Learning               747               0.19
# 166          166                                  Web Data Mining and Analysis               747               0.19
# 167          161                          Interconnection Networks and Systems               741               0.19
# 168          167                                 ICT in Developing Communities               738               0.19
# 169          171                              Error Correcting Code Techniques               733               0.19
# 170          172                          Security in Wireless Sensor Networks               730               0.19
# 171          165                              Open Source Software Innovations               729               0.19
# 172          169                              Optimization and Search Problems               717               0.18
# 173          173                         Advanced Database Systems and Queries               711               0.18
# 174          174                        Cybercrime and Law Enforcement Studies               698               0.18
# 175          176                            Embedded Systems Design Techniques               691               0.18
# 176          175                            Cellular Automata and Applications               664               0.17
# 177          178                               Wireless Networks and Protocols               649               0.17
# 178          179            Advanced Computational Techniques and Applications               648               0.17
# 179          177                          Polynomial and algebraic computation               624               0.16
# 180          180                                   Digital and Cyber Forensics               613               0.16
# 181          181                      Wireless Communication Networks Research               613               0.16
# 182          183                    Advanced Authentication Protocols Security               604               0.16
# 183          182                        Network Traffic and Congestion Control               601               0.15
# 184          184                                   Graph Theory and Algorithms               577               0.15
# 185          188                         Higher Education and Teaching Methods               569               0.15
# 186          187                  Model-Driven Software Engineering Techniques               566               0.15
# 187          186                   Stochastic Gradient Optimization Techniques               563               0.14
# 188          185                         AI-based Problem Solving and Planning               562               0.14
# 189          191                           E-Learning and Knowledge Management               560               0.14
# 190          190                         Image and Object Detection Techniques               556               0.14
# 191          192                          Authorship Attribution and Profiling               547               0.14
# 192          189                              Numerical Methods and Algorithms               546               0.14
# 193          194                    Software Reliability and Analysis Research               541               0.14
# 194          193                   Advanced Software Engineering Methodologies               539               0.14
# 195          195                         Information Retrieval and Data Mining               521               0.13
# 196          196                     Video Coding and Compression Technologies               512               0.13
# 197          197                      Constraint Satisfaction and Optimization               479               0.12
# 198          198                                  Real-Time Systems Scheduling               470               0.12
# 199          199                        Educational Innovations and Technology               467               0.12
# 200          201          Library Collection Development and Digital Resources               459               0.12
# 201          200                     Network Time Synchronization Technologies               455               0.12
# 202          202                           Innovative Educational Technologies               455               0.12
# 203          205                            Interactive and Immersive Displays               442               0.11
# 204          203                                 Petri Nets in System Modeling               438               0.11
# 205          206                             Peer-to-Peer Network Technologies               433               0.11
# 206          207                            Law, AI, and Intellectual Property               425               0.11
# 207          204                Contact Mechanics and Variational Inequalities               418               0.11
# 208          209                             Educational Research and Pedagogy               412               0.11
# 209          208          Distributed Sensor Networks and Detection Algorithms               411               0.11
# 210          210                           Cryptography and Residue Arithmetic               398               0.10
# 211          211                                  Technology and Data Analysis               398               0.10
# 212          212                          Engineering Education and Technology               394               0.10
# 213          213                                          Data Analysis with R               377               0.10
# 214          214                           Advanced Decision-Making Techniques               372               0.10
# 215          215                               Persona Design and Applications               363               0.09
# 216          216             Bluetooth and Wireless Communication Technologies               358               0.09
# 217          217                               Age of Information Optimization               356               0.09
# 218          218                                   Multimedia Learning Systems               356               0.09
# 219          219                 Scientific Research and Philosophical Inquiry               346               0.09
# 220          220                Environmental Engineering and Cultural Studies               340               0.09
# 221          222                                      Web and Library Services               329               0.08
# 222          221                               VLSI and Analog Circuit Testing               328               0.08
# 223          223                           Usability and User Interface Design               313               0.08
# 224          224                         Cybersecurity and Information Systems               313               0.08
# 225          226                                  AI and Big Data Applications               302               0.08
# 226          225                           Digital Image Processing Techniques               298               0.08
# 227          227                        Statistical and Computational Modeling               283               0.07
# 228          229                     Information Retrieval and Search Behavior               271               0.07
# 229          228                      Digital Filter Design and Implementation               271               0.07
# 230          231                                   Mobile and Web Applications               264               0.07
# 231          230                            Currency Recognition and Detection               262               0.07
# 232          233                         Mobile Agent-Based Network Management               255               0.07
# 233          235                             Transportation Systems and Safety               250               0.06
# 234          234                                Expert finding and Q&A systems               249               0.06
# 235          232                          Adaptive Dynamic Programming Control               248               0.06
# 236          236                                 Quantum-Dot Cellular Automata               237               0.06
# 237          237                        Digital Rights Management and Security               228               0.06
# 238          238                        Educational Challenges and Innovations               228               0.06
# 239          239            Mathematics, Computing, and Information Processing               222               0.06
# 240          240                              Computer Science and Engineering               221               0.06
# 241          241                      Web Application Security Vulnerabilities               215               0.06
# 242          242            Innovations in Education and Learning Technologies               210               0.05
# 243          243  Advanced Computational Techniques in Science and Engineering               206               0.05
# 244          245                    Network Packet Processing and Optimization               203               0.05
# 245          244                                AI and Multimedia in Education               203               0.05
# 246          247                                     IoT-based Control Systems               197               0.05
# 247          246                            Smart Systems and Machine Learning               197               0.05
# 248          249                              Educational Systems and Policies               192               0.05
# 249          248                         QR Code Applications and Technologies               192               0.05
# 250          250                       Library Science and Information Systems               192               0.05
# 251          251                                 Digital Education and Society               181               0.05
# 252          252                   Linguistic Studies and Language Acquisition               177               0.05
# 253          253                      Advanced Statistical Modeling Techniques               173               0.04
# 254          254                                     Internet of Things and AI               162               0.04
# 255          255                              Cognitive Computing and Networks               160               0.04
# 256          256                               Technology and Security Systems               158               0.04
# 257          257                               Modeling and Simulation Systems               151               0.04
# 258          258                                  Digital Media and Philosophy               146               0.04
# 259          259                   Advanced Technologies and Applied Computing               114               0.03
# 260          260                          Artificial Intelligence in Education               107               0.03
# 261          261                           Healthcare during COVID-19 Pandemic               104               0.03
# 262          262                          Artificial Intelligence Applications               101               0.03
# 263          263                     Mathematical Control Systems and Analysis                99               0.03
# 264          264                                 Image and Video Stabilization                99               0.03
# 265          265                           Spreadsheets and End-User Computing                98               0.03
# 266          266                    Wireless Sensor Networks for Data Analysis                97               0.02
# 267          267                               Web visibility and informetrics                96               0.02
# 268          268                          Web Applications and Data Management                94               0.02
# 269          269                               Library Science and Information                92               0.02
# 270          270                           Advanced Technology in Applications                82               0.02
# 271          271                         Educational Technology and E-Learning                81               0.02
# 272          272      Information Systems Education and Curriculum Development                78               0.02
# 273          273                            Scientific Research and Technology                77               0.02
# 274          274            Internet of Things and Social Network Interactions                73               0.02
# 275          275                          Educational Robotics and Engineering                70               0.02
# 276          277                     Intuitionistic Fuzzy Systems Applications                66               0.02
# 277          276                            Educational Methods and Technology                66               0.02
# 278          278                               Media and Digital Communication                61               0.02
# 279          279                        Information Architecture and Usability                60               0.02
# 280          280               Cloud Computing and Remote Desktop Technologies                54               0.01
# 281          281                                  Big Data and Digital Economy                50               0.01
# 282          282                        Educational and Technological Research                50               0.01
# 283          283                       Educational Technology and Optimization                49               0.01
# 284          284                            Educational Management and Quality                47               0.01
# 285          285                             Information Science and Libraries                44               0.01
# 286          286                         Cultural Insights and Digital Impacts                43               0.01
# 287          287          Artificial Intelligence and Decision Support Systems                40               0.01
# 288          289                        Engineering and Information Technology                40               0.01
# 289          290               Chemical and Environmental Engineering Research                39               0.01
# 290          291                              Chaos, Complexity, and Education                38               0.01
# 291          288                             History of Computing Technologies                38               0.01
# 292          292                         Experience-Based Knowledge Management                32               0.01
# 293          293                    Diverse Interdisciplinary Research Studies                31               0.01
# 294          294                               Thoreau and American Literature                25               0.01
# 295          295                            Educational Technology in Learning                22               0.01
# 296          296                       Psychiatry, Mental Health, Neuroscience                19               0.00
# 297          297                                Energy Efficiency in Computing                15               0.00
# 298          298                              Technology and Education Systems                14               0.00
# 299          299                             Diverse Research and Applications                14               0.00
# 300          300                             Bioethics and Human Rights Issues                13               0.00
# 301          301                          Education, Technology, and Economics                12               0.00
# 302           76                    Model-Based Clustering with Mixture Models                 1               0.00
# 303            0                                   Natural Language Processing                 1               0.00
# 304           15             Wireless Sensor Networks: Survey and Applications                 1               0.00
# 305           46                  Advanced Cryptographic Schemes and Protocols                 1               0.00
# 306           96                Distributed Storage Systems and Network Coding                 1               0.00
# 307          117                 Log Analysis and System Performance Diagnosis                 1               0.00
# 308           68                          Digital Image Correlation Techniques                 1               0.00
# 309            6        Deep Learning in Computer Vision and Image Recognition                 1               0.00

# %%
fig = px.histogram(
    df_topic_stat,
    x='topic_display_name',
    y='number_of_papers',
    title='Number of papers per Topic'
)
fig.update_xaxes(showticklabels=False)
fig.update_layout(xaxis_title='Topics')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_semibalanced_by_topics = wr.athena.read_sql_query("""
WITH
filtered_by_min_topic_count AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_id ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
    WHERE
        openalex_primary_topic_count > 400 -- ~0.1% cutoff rate
),
stratified_sampling AS (
    SELECT
        *
    FROM
        filtered_by_min_topic_count
    WHERE
        topic_row_number < 3000 -- elbow-logic 
)
SELECT 
    COUNT(*) AS number_of_papers,
    COUNT(DISTINCT openalex_primary_topic_subfield_id) AS number_of_subfields,
    COUNT(DISTINCT openalex_primary_topic_id) AS number_of_topics
FROM
    stratified_sampling
""", '02_stg')
df_semibalanced_by_topics
# Out:
#    number_of_papers  number_of_subfields  number_of_topics
# 0            308153                   11               211

# %%
df_subfield_semibalanced_stat = wr.athena.read_sql_query("""
WITH
filtered_by_min_topic_count AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_id ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
    WHERE
        openalex_primary_topic_count > 400 -- ~0.1% cutoff rate
),
stratified_sampling AS (
    SELECT
        *
    FROM
        filtered_by_min_topic_count
    WHERE
        topic_row_number < 3000 -- elbow-logic 
)
SELECT 
    openalex_primary_topic_subfield_id, 
    openalex_primary_topic_subfield_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM stratified_sampling), 2) AS percent_of_papers
FROM
    stratified_sampling
GROUP BY
    openalex_primary_topic_subfield_id, 
    openalex_primary_topic_subfield_display_name
ORDER BY
    number_of_papers DESC
 """, '02_stg')
df_subfield_semibalanced_stat.head()
# Out:
#    openalex_primary_topic_subfield_id openalex_primary_topic_subfield_display_name  number_of_papers  percent_of_papers
# 0                                1702                      Artificial Intelligence            103665              33.64
# 1                                1707      Computer Vision and Pattern Recognition             58171              18.88
# 2                                1710                          Information Systems             42779              13.88
# 3                                1705         Computer Networks and Communications             36350              11.80
# 4                                1703         Computational Theory and Mathematics             24741               8.03

# %%
fig = px.histogram(
    df_subfield_semibalanced_stat,
    x='openalex_primary_topic_subfield_display_name',
    y='number_of_papers',
    title='Number of papers per Subfield'
)
fig.update_layout(xaxis_title='')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_topic_semibalanced_stat = wr.athena.read_sql_query("""
WITH
filtered_by_min_topic_count AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_id ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
    WHERE
        openalex_primary_topic_count > 400 -- ~0.1% cutoff rate
),
stratified_sampling AS (
    SELECT
        *
    FROM
        filtered_by_min_topic_count
    WHERE
        topic_row_number < 3000 -- elbow-logic 
)
SELECT 
    openalex_primary_topic_id, 
    openalex_primary_topic_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM stratified_sampling), 2) AS percent_of_papers
FROM
    stratified_sampling
GROUP BY
    openalex_primary_topic_id, 
    openalex_primary_topic_display_name
ORDER BY
    number_of_papers DESC
 """, '02_stg')
df_topic_semibalanced_stat.head()
# Out:
#    openalex_primary_topic_id              openalex_primary_topic_display_name  number_of_papers  percent_of_papers
# 0                      10764          Privacy-Preserving Technologies in Data              2999               0.97
# 1                      10270  Blockchain Technology Applications and Security              2999               0.97
# 2                      10036             Advanced Neural Network Applications              2999               0.97
# 3                      10664            Sentiment Analysis and Opinion Mining              2999               0.97
# 4                      10260                    Software Engineering Research              2999               0.97

# %%
fig = px.histogram(
    df_topic_semibalanced_stat,
    x='openalex_primary_topic_display_name',
    y='number_of_papers',
    title='Number of papers per Topic'
)
fig.update_xaxes(showticklabels=False)
fig.update_layout(xaxis_title='Topics')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_subfield_semibalanced_02_stat = wr.athena.read_sql_query("""
WITH
works_numbered AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_subfield_id ORDER BY RANDOM()) AS subfield_row_number
    FROM
        stg_unified_works_filtered
),
stratified_sampling AS (
    SELECT
        *
    FROM
        works_numbered
    WHERE
        subfield_row_number < 36000 -- elbow-logic 
)
SELECT 
    openalex_primary_topic_subfield_id, 
    openalex_primary_topic_subfield_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM stratified_sampling), 2) AS percent_of_papers
FROM
    stratified_sampling
GROUP BY
    openalex_primary_topic_subfield_id, 
    openalex_primary_topic_subfield_display_name
ORDER BY
    number_of_papers DESC
 """, '02_stg')
df_subfield_semibalanced_02_stat.head()
# Out:
#    openalex_primary_topic_subfield_id openalex_primary_topic_subfield_display_name  number_of_papers  percent_of_papers
# 0                                1705         Computer Networks and Communications             35999              16.05
# 1                                1707      Computer Vision and Pattern Recognition             35999              16.05
# 2                                1702                      Artificial Intelligence             35999              16.05
# 3                                1710                          Information Systems             35999              16.05
# 4                                1703         Computational Theory and Mathematics             34092              15.20

# %%
fig = px.histogram(
    df_subfield_semibalanced_02_stat,
    x='openalex_primary_topic_subfield_display_name',
    y='number_of_papers',
    title='Number of papers per Subfield'
)
fig.update_layout(xaxis_title='')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_topic_semibalanced_02_stat = wr.athena.read_sql_query("""
WITH
works_numbered AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_subfield_id ORDER BY RANDOM()) AS subfield_row_number
    FROM
        stg_unified_works_filtered
),
stratified_sampling AS (
    SELECT
        *
    FROM
        works_numbered
    WHERE
        subfield_row_number < 36000 -- elbow-logic 
)
SELECT 
    openalex_primary_topic_id, 
    openalex_primary_topic_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM stratified_sampling), 2) AS percent_of_papers
FROM
    stratified_sampling
GROUP BY
    openalex_primary_topic_id, 
    openalex_primary_topic_display_name
ORDER BY
    number_of_papers DESC
 """, '02_stg')
df_topic_semibalanced_02_stat.head()
# Out:
#    openalex_primary_topic_id              openalex_primary_topic_display_name  number_of_papers  percent_of_papers
# 0                      10211             Computational Drug Discovery Methods             11454               5.11
# 1                      10028                                   Topic Modeling              4473               1.99
# 2                      10270  Blockchain Technology Applications and Security              4248               1.89
# 3                      11122                    Online Learning and Analytics              3917               1.75
# 4                      10273                       IoT and Edge/Fog Computing              3815               1.70

# %%
fig = px.histogram(
    df_topic_semibalanced_02_stat,
    x='openalex_primary_topic_display_name',
    y='number_of_papers',
    title='Number of papers per Topic'
)
fig.update_xaxes(showticklabels=False)
fig.update_layout(xaxis_title='Topics')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_topic_semibalanced_03_stat = wr.athena.read_sql_query("""
WITH
works_numbered AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_subfield_display_name ORDER BY RANDOM()) AS subfield_row_number,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_display_name ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
),
stratified_sampling AS (
    SELECT
        *
    FROM
        works_numbered
    WHERE
        subfield_row_number < 20000 AND -- elbow-logic 
        topic_row_number < 2500 -- elbow-logic 
),
counted_by_topic AS (
    SELECT
        *,
        COUNT(*) OVER (PARTITION BY openalex_primary_topic_display_name) AS new_topic_count
    FROM
        stratified_sampling
),
filtered_by_min_topic_count AS (
    SELECT
        *
    FROM
        counted_by_topic
    WHERE
        new_topic_count > 400 -- ~0.1% cutoff rate
)
SELECT 
    openalex_primary_topic_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM stratified_sampling), 2) AS percent_of_papers
FROM
    filtered_by_min_topic_count
GROUP BY
    openalex_primary_topic_display_name
ORDER BY
    number_of_papers DESC
 """, '02_stg')
display(df_topic_semibalanced_03_stat.head())
df_topic_semibalanced_03_stat.tail()
# Out:
#         openalex_primary_topic_display_name  number_of_papers  percent_of_papers
# 0      Computational Drug Discovery Methods              2499                1.8
# 1  Virtual Reality Applications and Impacts              2499                1.8
# 2             Online Learning and Analytics              2499                1.8
# 3               Speech and Audio Processing              2499                1.8
# 4                Music and Audio Processing              2499                1.8
#                openalex_primary_topic_display_name  number_of_papers  percent_of_papers
# 101  Neural Networks Stability and Synchronization               457               0.33
# 102        Data Mining Algorithms and Applications               450               0.32
# 103             Interactive and Immersive Displays               442               0.32
# 104                Economic Growth and Development               404               0.29
# 105        Domain Adaptation and Few-Shot Learning               401               0.29

# %%
fig = px.histogram(
    df_topic_semibalanced_03_stat,
    x='openalex_primary_topic_display_name',
    y='number_of_papers',
    title='Number of papers per Topic'
)
fig.update_xaxes(showticklabels=False)
fig.update_layout(xaxis_title='Topics')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_51.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_subfield_semibalanced_03_stat = wr.athena.read_sql_query("""
WITH
works_numbered AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_subfield_display_name ORDER BY RANDOM()) AS subfield_row_number,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_display_name ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
),
stratified_sampling AS (
    SELECT
        *
    FROM
        works_numbered
    WHERE
        subfield_row_number < 20000 AND -- elbow-logic 
        topic_row_number < 2500 -- elbow-logic 
),
counted_by_topic AS (
    SELECT
        *,
        COUNT(*) OVER (PARTITION BY openalex_primary_topic_display_name) AS new_topic_count
    FROM
        stratified_sampling
),
filtered_by_min_topic_count AS (
    SELECT
        *
    FROM
        counted_by_topic
    WHERE
        new_topic_count > 400 -- ~0.1% cutoff rate
)
SELECT 
    openalex_primary_topic_subfield_id, 
    openalex_primary_topic_subfield_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM stratified_sampling), 2) AS percent_of_papers
FROM
    filtered_by_min_topic_count
GROUP BY
    openalex_primary_topic_subfield_id, 
    openalex_primary_topic_subfield_display_name
ORDER BY
    number_of_papers DESC
 """, '02_stg')
df_subfield_semibalanced_03_stat.head()
# Out:
#    openalex_primary_topic_subfield_id openalex_primary_topic_subfield_display_name  number_of_papers  percent_of_papers
# 0                                1707      Computer Vision and Pattern Recognition             17058              12.27
# 1                                1711                            Signal Processing             14926              10.74
# 2                                1705         Computer Networks and Communications             14358              10.33
# 3                                1703         Computational Theory and Mathematics             13586               9.78
# 4                                1710                          Information Systems             11588               8.34

# %%
fig = px.histogram(
    df_subfield_semibalanced_03_stat,
    x='openalex_primary_topic_subfield_display_name',
    y='number_of_papers',
    title='Number of papers per Subfield'
)
fig.update_layout(xaxis_title='')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_53.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_semibalanced_03_stat = wr.athena.read_sql_query("""
WITH
works_numbered AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_subfield_display_name ORDER BY RANDOM()) AS subfield_row_number,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_display_name ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
),
stratified_sampling AS (
    SELECT
        *
    FROM
        works_numbered
    WHERE
        subfield_row_number < 20000 AND -- elbow-logic 
        topic_row_number < 2500 -- elbow-logic 
),
counted_by_topic AS (
    SELECT
        *,
        COUNT(*) OVER (PARTITION BY openalex_primary_topic_display_name) AS new_topic_count
    FROM
        stratified_sampling
),
filtered_by_min_topic_count AS (
    SELECT
        *
    FROM
        counted_by_topic
    WHERE
        new_topic_count > 400 -- ~0.1% cutoff rate
)
SELECT 
    COUNT(*) AS number_of_papers,
    COUNT(DISTINCT openalex_primary_topic_subfield_display_name) AS number_of_subfields,
    COUNT(DISTINCT openalex_primary_topic_display_name) AS number_of_topics
FROM
    filtered_by_min_topic_count
 """, '02_stg')
df_semibalanced_03_stat.head()
# Out:
#    number_of_papers  number_of_subfields  number_of_topics
# 0            107724                   11               106

# %%
df_works_semibalanced = wr.athena.read_sql_query("""
WITH
works_numbered AS (
    SELECT
        *,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_subfield_display_name ORDER BY RANDOM()) AS subfield_row_number,
        ROW_NUMBER() OVER (PARTITION BY openalex_primary_topic_display_name ORDER BY RANDOM()) AS topic_row_number
    FROM
        stg_unified_works_filtered
),
stratified_sampling AS (
    SELECT
        *
    FROM
        works_numbered
    WHERE
        subfield_row_number < 20000 AND -- elbow-logic 
        topic_row_number < 2500 -- elbow-logic 
),
counted_by_topic AS (
    SELECT
        *,
        COUNT(*) OVER (PARTITION BY openalex_primary_topic_display_name) AS new_topic_count
    FROM
        stratified_sampling
),
filtered_by_min_topic_count AS (
    SELECT
        *
    FROM
        counted_by_topic
    WHERE
        new_topic_count > 400 -- ~0.1% cutoff rate
),
----
subfield_counts AS (
    SELECT
        openalex_primary_topic_subfield_display_name,
        COUNT(*) AS openalex_primary_topic_subfield_count
    FROM
        filtered_by_min_topic_count
    GROUP BY
        openalex_primary_topic_subfield_display_name
),
subfield_index AS (
    SELECT
        *,
        (ROW_NUMBER() OVER () -1) AS openalex_primary_topic_subfield_index
    FROM
        subfield_counts
),
topic_counts AS (
    SELECT
        openalex_primary_topic_display_name,
        COUNT(*) AS openalex_primary_topic_count
    FROM
        filtered_by_min_topic_count
    GROUP BY
        openalex_primary_topic_display_name
),
topic_index AS (
    SELECT
        *,
        (ROW_NUMBER() OVER () -1) AS openalex_primary_topic_index
    FROM
        topic_counts
),
reindexed AS (
    SELECT    
        stg_unified_works_filtered.id_semanticscholar,
        stg_unified_works_filtered.id_mag,
        stg_unified_works_filtered.id_doi,
        stg_unified_works_filtered.id_arxiv,
        stg_unified_works_filtered.publication_year,
        stg_unified_works_filtered.publication_date,
        stg_unified_works_filtered.license,
        stg_unified_works_filtered.license_allows_derivative_reuse,
        stg_unified_works_filtered.source_url,
        stg_unified_works_filtered.has_id_mag,
        stg_unified_works_filtered.has_id_doi,
        stg_unified_works_filtered.has_id_mag_or_doi,
        stg_unified_works_filtered.openalex_id_openalex,
        stg_unified_works_filtered.openalex_id_doi,
        stg_unified_works_filtered.openalex_language,
        stg_unified_works_filtered.openalex_primary_topic_id,
        stg_unified_works_filtered.openalex_primary_topic_display_name,
        stg_unified_works_filtered.openalex_primary_topic_count,
        topic_index.openalex_primary_topic_index,
        stg_unified_works_filtered.openalex_primary_topic_subfield_id,
        stg_unified_works_filtered.openalex_primary_topic_subfield_display_name,
        stg_unified_works_filtered.openalex_primary_topic_subfield_count,
        subfield_index.openalex_primary_topic_subfield_index,
        stg_unified_works_filtered.openalex_primary_topic_field_id,
        stg_unified_works_filtered.openalex_primary_topic_field_display_name,
        stg_unified_works_filtered.openalex_primary_topic_domain_id,
        stg_unified_works_filtered.openalex_primary_topic_domain_display_name,
        stg_unified_works_filtered.openalex_joined_on,
        stg_unified_works_filtered.title,
        stg_unified_works_filtered.content_abstract,
        stg_unified_works_filtered.content_text,
        stg_unified_works_filtered.annotations_paragraph,
        stg_unified_works_filtered.annotations_section_header
    FROM
        stg_unified_works_filtered
        
    LEFT JOIN
        topic_index
    ON
        stg_unified_works_filtered.openalex_primary_topic_display_name = topic_index.openalex_primary_topic_display_name
    
    LEFT JOIN
        subfield_index
    ON
        stg_unified_works_filtered.openalex_primary_topic_subfield_display_name = subfield_index.openalex_primary_topic_subfield_display_name
),
reindexed_stratified AS (
    SELECT 
        *,
        NTILE(10) OVER( PARTITION BY openalex_primary_topic_display_name ORDER BY random()) AS bucket_10p
    FROM
        reindexed
),
reindexed_tagged AS (
    SELECT 
        *,
        CASE 
            WHEN bucket_10p = 1 THEN 'test'
            WHEN bucket_10p = 2 THEN 'validation'
            ELSE 'train'
        END AS subset --80-10-10 split
    FROM
        reindexed_stratified
    WHERE
        openalex_language='en' AND
        license_allows_derivative_reuse=1
)
SELECT * FROM reindexed_tagged ORDER BY RANDOM() LIMIT 100
 """, '02_stg')
df_works_semibalanced.head(100)
# Out:
#     id_semanticscholar      id_mag                               id_doi  \
# 0            247655188        <NA>          10.1109/access.2022.3161470
# 1            252243320        <NA>                    10.3390/s22186832
# 2            253290325        <NA>           10.3390/healthcare10112189
# 3            240763749        <NA>                10.31235/osf.io/aj34w
# 4             18957185  2168768030           10.1186/1687-1499-2013-159
# ..                 ...         ...                                  ...
# 95           114707019  2566913441           10.5755/j01.eie.22.6.17230
# 96           237592250        <NA>                 10.1155/2021/2122095
# 97           273629230        <NA>         10.6007/ijarped/v13-i4/22957
# 98            22278945  2154883722                         10.5772/5785
# 99           266149963        <NA>  10.18653/v1/2023.findings-emnlp.333
#
#       id_arxiv  publication_year publication_date license  \
# 0         <NA>              2022             <NA>    CCBY
# 1         <NA>              2022       2022-09-01    CCBY
# 2         <NA>              2022       2022-10-31    CCBY
# 3         <NA>              2020       2020-01-24    CCBY
# 4         <NA>              2013       2013-06-11    CCBY
# ..         ...               ...              ...     ...
# 95        <NA>              2016       2016-08-12    CCBY
# 96        <NA>              2021       2021-09-21    CCBY
# 97        <NA>              2024       2024-10-25    CCBY
# 98  cs/0601062              2005       2005-09-01    CCBY
# 99  2312.04807              2023       2023-12-08    CCBY
#
#     license_allows_derivative_reuse  \
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 1
# ..                              ...
# 95                                1
# 96                                1
# 97                                1
# 98                                1
# 99                                1
#
#                                           source_url  has_id_mag  ...  \
# 0        https://doi.org/10.1109/ACCESS.2022.3161470           0  ...
# 1   https://pmc.ncbi.nlm.nih.gov/articles/PMC9505052           0  ...
# 2   https://pmc.ncbi.nlm.nih.gov/articles/PMC9690420           0  ...
# 3              https://doi.org/10.31235/osf.io/aj34w           0  ...
# 4         https://doi.org/10.1186/1687-1499-2013-159           1  ...
# ..                                               ...         ...  ...
# 95        https://doi.org/10.5755/J01.EIE.22.6.17230           1  ...
# 96  https://pmc.ncbi.nlm.nih.gov/articles/PMC8455217           0  ...
# 97      https://doi.org/10.6007/ijarped/v13-i4/22957           0  ...
# 98                  https://arxiv.org/abs/cs/0601062           1  ...
# 99                  https://arxiv.org/abs/2312.04807           0  ...
#
#     openalex_primary_topic_domain_id  \
# 0                                  3
# 1                                  3
# 2                                  3
# 3                                  3
# 4                                  3
# ..                               ...
# 95                                 3
# 96                                 3
# 97                                 3
# 98                                 3
# 99                                 3
#
#     openalex_primary_topic_domain_display_name  openalex_joined_on  \
# 0                            Physical Sciences                 doi
# 1                            Physical Sciences                 doi
# 2                            Physical Sciences                 doi
# 3                            Physical Sciences                 doi
# 4                            Physical Sciences                 doi
# ..                                         ...                 ...
# 95                           Physical Sciences                 doi
# 96                           Physical Sciences                 doi
# 97                           Physical Sciences                 doi
# 98                           Physical Sciences                 doi
# 99                           Physical Sciences                 doi
#
#                                                 title  \
# 0   A Comparison of Promethee and TOPSIS Technique...
# 1   Efficient Clustering for Continuous Occupancy ...
# 2   A Multimodal Auxiliary Classification System f...
# 3   Platform Governance as Reflexive Coordination ...
# 4   A new mathematical analysis of the probability...
# ..                                                ...
# 95  Interconnection Contracts between Service and ...
# 96  Analysis on Health Information Acquisition of ...
# 97  The Problems of the Effectiveness of School-En...
# 98  Study of Self-Organization Model of Multiple M...
# 99  Improving Neural Machine Translation by Multi-...
#
#                                      content_abstract  \
# 0   The uncertainty in the data is an obstacle in ...
# 1   This paper proposes a novel method for occupan...
# 2   Histopathological examination is an important ...
# 3   Digital platforms have become dominant players...
# 4   Cognitive radio (CR) enriches wireless technol...
# ..                                                ...
# 95  This paper addresses interconnection contracts...
# 96  This study aims to explore phenomena and laws ...
# 97  The development of vocational education cannot...
# 98  A good organization model of multiple mobile r...
# 99  Improving neural machine translation (NMT) sys...
#
#                                          content_text  \
# 0   \nI. INTRODUCTION\n\nM ANY complicated problem...
# 1   \nIntroduction\n\nMapping is one of the fundam...
# 2   \nIntroduction\n\nThe incidence of osteosarcom...
# 3   \nBackground\n\nDigital platforms have become ...
# 4   \nIntroduction\n\nThe rapid increase of wirele...
# ..                                                ...
# 95  \nI. INTRODUCTION\n\nThe permanent growth of I...
# 96  \nIntroduction\n\nWith the popularity of the I...
# 97  \nIntroduction\n\nTaking an overview of the de...
# 98  \nIntroduction\n\nAt present, the research of ...
# 99  \nIntroduction\n\nIn the workflow of translati...
#
#                                 annotations_paragraph  \
# 0   [{"attributes":null,"end":8340,"start":18},{"a...
# 1   [{"attributes":null,"end":246,"start":15},{"at...
# 2   [{"attributes":null,"end":584,"start":15},{"at...
# 3   [{"attributes":null,"end":1087,"start":13},{"a...
# 4   [{"attributes":null,"end":890,"start":15},{"at...
# ..                                                ...
# 95  [{"attributes":null,"end":1041,"start":18},{"a...
# 96  [{"attributes":null,"end":1546,"start":15},{"a...
# 97  [{"attributes":null,"end":984,"start":15},{"at...
# 98  [{"attributes":null,"end":1509,"start":15},{"a...
# 99  [{"attributes":null,"end":882,"start":15},{"at...
#
#                            annotations_section_header  bucket_10p  subset
# 0   [{"attributes":null,"end":16,"start":1},{"attr...           4   train
# 1   [{"attributes":{"n":"1."},"end":13,"start":1},...           5   train
# 2   [{"attributes":{"n":"1."},"end":13,"start":1},...           5   train
# 3   [{"attributes":null,"end":11,"start":1},{"attr...          10   train
# 4   [{"attributes":{"n":"1"},"end":13,"start":1},{...           6   train
# ..                                                ...         ...     ...
# 95  [{"attributes":null,"end":16,"start":1},{"attr...           7   train
# 96  [{"attributes":{"n":"1."},"end":13,"start":1},...           8   train
# 97  [{"attributes":null,"end":13,"start":1},{"attr...           8   train
# 98  [{"attributes":{"n":"1."},"end":13,"start":1},...          10   train
# 99  [{"attributes":{"n":"1"},"end":13,"start":1},{...          10   train
#
# [100 rows x 35 columns]

# %%
wr.athena.read_sql_query("""
    SELECT 
        COUNT(*) AS number_of_papers,
        COUNT(DISTINCT subfield_index) AS number_of_subfields,
        COUNT(DISTINCT topic_index) AS number_of_topics
    FROM
        unified_works_semibalanced
""", '03_core')
# Out:
#    number_of_papers  number_of_subfields  number_of_topics
# 0            108174                   11               107

# %%
df_topic_semibalanced_final_stat = wr.athena.read_sql_query("""
SELECT 
    topic_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM unified_works_semibalanced), 2) AS percent_of_papers
FROM
    unified_works_semibalanced
GROUP BY
    topic_display_name
ORDER BY
    number_of_papers DESC
 """, '03_core')
display(df_topic_semibalanced_final_stat.head())
df_topic_semibalanced_final_stat.tail()
# Out:
#                          topic_display_name  number_of_papers  percent_of_papers
# 0  Virtual Reality Applications and Impacts              2499               2.31
# 1             Online Learning and Analytics              2499               2.31
# 2               Speech and Audio Processing              2499               2.31
# 3                Music and Audio Processing              2499               2.31
# 4      Computational Drug Discovery Methods              2499               2.31
#                              topic_display_name  number_of_papers  percent_of_papers
# 102     Data Mining Algorithms and Applications               457               0.42
# 103          Interactive and Immersive Displays               442               0.41
# 104  Adversarial Robustness in Machine Learning               432               0.40
# 105                 Spam and Phishing Detection               423               0.39
# 106             Economic Growth and Development               405               0.37

# %%
fig = px.histogram(
    df_topic_semibalanced_final_stat,
    x='topic_display_name',
    y='number_of_papers',
    title='Number of papers per Topic'
)
fig.update_xaxes(showticklabels=False)
fig.update_layout(xaxis_title='Topics')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_subfield_semibalanced_final_stat = wr.athena.read_sql_query("""
SELECT 
    subfield_display_name,
    COUNT(*) AS number_of_papers,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) AS c FROM unified_works_semibalanced), 2) AS percent_of_papers
FROM
    unified_works_semibalanced
GROUP BY
    subfield_display_name
ORDER BY
    number_of_papers DESC
 """, '03_core')
df_subfield_semibalanced_final_stat
# Out:
#                           subfield_display_name  number_of_papers  percent_of_papers
# 0       Computer Vision and Pattern Recognition             17031              15.74
# 1                             Signal Processing             14926              13.80
# 2          Computer Networks and Communications             14287              13.21
# 3          Computational Theory and Mathematics             13748              12.71
# 4                           Information Systems             12436              11.50
# 5                       Artificial Intelligence              9850               9.11
# 6                    Human-Computer Interaction              8467               7.83
# 7                 Computer Science Applications              6971               6.44
# 8   Computer Graphics and Computer-Aided Design              4059               3.75
# 9                     Hardware and Architecture              3883               3.59
# 10                                     Software              2516               2.33

# %%
fig = px.histogram(
    df_subfield_semibalanced_final_stat,
    x='subfield_display_name',
    y='number_of_papers',
    title='Number of papers per Subfield'
)
fig.update_layout(xaxis_title='')
fig.update_layout(yaxis_title='Number of papers')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
